# %% [markdown]
# ### Adversarial Discriminative Domain Adaptation

# %%
# import modules and libraries
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable

# functions to create datasets and models
from data.data import *
from models.models import *

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available')
else:
    print('CUDA is available')
    device = torch.device('cuda')
# Out:
# CUDA is available

# %% [markdown]
# ### Parameters

# %%
"""Parameters for this experiment"""
# params for loading the data
path = 'data/CWRU/bearing/'
source_domain = 'A'
target_domains = ['B', 'C', 'D', 'E', 'F', 'G', 'H']

# params for configuring the model
input_dim = 1
hidden_dim = 256
output_dim = 10
drop_prob = 0.5

# params for training the model
epochs_pre = 30 # pre-training
epochs = 30

# optimizing the model
lr = 1e-4
d_lr = 1e-4
batch_size = 20
beta1 = 0.5
beta2 = 0.9

# %% [markdown]
# ### Data Loading

# %%
# source domain data for training, validating and testing
train_dataloader_src, val_dataloader_src, test_dataloader_src = generate_dataloaders(path, source_domain, batch_size)

# target domain data for validating and testing
train_dataloader_tgt, val_dataloader_tgt, test_dataloader_tgt = [], [], []
for target_domain in target_domains:
    train_dataloader_temp, val_dataloader_temp, test_dataloader_temp = generate_dataloaders(path, target_domain, batch_size)
    
    train_dataloader_tgt.append(train_dataloader_temp)
    val_dataloader_tgt.append(val_dataloader_temp)
    test_dataloader_tgt.append(test_dataloader_temp)

# %% [markdown]
# ### Model

# %%
encoder_src = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim # hidden layers 64
)

classifier = Classifier_AMDA(
    hidden_dim=hidden_dim, # hidden layers 64
    output_dim=output_dim, # 3 classes (healthy, inner- and outer-bearing damages)
    dropout=drop_prob # dropout prob 0.5
)

encoder_tgt = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim, # hidden layers 64
)

discriminator = Discriminator(
    hidden_dim=hidden_dim
)

if train_on_gpu:
    encoder_src = encoder_src.to(device)
    classifier = classifier.to(device)
    encoder_tgt = encoder_tgt.to(device)
    discriminator = discriminator.to(device)

# %% [markdown]
# #### Functions for training and testing the model

# %%
# functions for training source encoder and shared classifier
def train_src(encoder, classifier):
    """Train the source encoder and shared classifier on source domain"""
    encoder.train()
    classifier.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        list(encoder.parameters()) + list(classifier.parameters()),
        lr=lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs_pre):
        accuracies = []
        losses = []

        for batch_idx, (x_src, y_src) in enumerate(train_dataloader_src):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            optimizer.zero_grad()

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            loss_src.backward()

            optimizer.step()

            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_src(encoder, classifier, phase = 'Val')
        print(f'\t Val Loss:{val_loss:0.2f} \t\t Val Acc:{val_acc:0.2f}')

    return encoder, classifier

# testing model on source domain
def evaluate_src(encoder, classifier, phase='Val'): # phase can be validate or test
    """Evaluate the trained network on source domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    dataloader = val_dataloader_src if phase == 'Val' else test_dataloader_src
    
    with torch.no_grad():
        for batch_idx, (x_src, y_src) in enumerate(dataloader):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            
            # append loss for each batch
            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# Continuous Unsupervised Adaptation (CUA)
# functions for training target encoder
def train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase):
    """Train the target encoder on target domains with source encoder and test the network"""
    encoder_tgt.train()
    discriminator.train()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        encoder_tgt.parameters(),
        lr=lr,
        betas=(beta1, beta2)
    )
    d_optimizer = Adam(
        discriminator.parameters(),
        lr=d_lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs):
        losses = []
        losses_d = []
        accuracies = []
        accuracies_d = []

        for batch_idx, ((x_src, y_src), (x_tgt, y_tgt)) in enumerate(zip(train_dataloader_src, train_dataloader_tgt[phase])):
            if(train_on_gpu):
                x_src, y_src = x_src.to(device), y_src.to(device)
                x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)

            optimizer.zero_grad()
            d_optimizer.zero_grad()

            # part 1: sequential unsupervised adaptation
            # learn e_src and _tgt: source and target mapping represenations
            e_src = encoder_src(x_src)
            e_tgt = encoder_tgt(x_tgt)
            e_concat = torch.concat((e_src.detach(), e_tgt.detach()), 0)
            # minimize distance between source and target empirical mapping distribution using adversarial discriminator
            d_concat = discriminator(e_concat)

            label_src = Variable(torch.ones(e_src.size(0)).long()).to(device)
            label_tgt = Variable(torch.zeros(e_tgt.size(0)).long()).to(device)
            label_concat = torch.cat((label_src, label_tgt), 0)

            loss_d = criterion(d_concat, label_concat)
            loss_d.backward()
            d_optimizer.step()

            e_tgt = encoder_tgt(x_tgt)
            pred_tgt = classifier(e_tgt)
            d_tgt = discriminator(e_tgt)
            label_tgt = Variable(torch.ones(e_tgt.size(0)).long()).to(device)
            loss = criterion(d_tgt, label_tgt)

            loss.backward()
            optimizer.step()
            
            # training (with replay) losses and accuracies
            losses.append(loss.detach().item()) # detach the loss from compute graph
            losses_d.append(loss_d.detach().item())
            accuracies.append(y_tgt.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            accuracies_d.append(torch.squeeze(d_concat.max(1)[1]).eq(label_concat.detach()).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train (with Adv) Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')
        print(f'\t Discriminator Loss:{torch.tensor(losses_d).mean():0.2f} \t Discriminator Acc:{torch.tensor(accuracies_d).mean():0.2f} ')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_tgt(encoder_tgt, classifier, val_dataloader_tgt[phase])
        print(f'\t Val (with Target) Loss:{val_loss:0.2f} \t Val (with Target) Acc:{val_acc:0.2f}')

    return encoder_tgt
    
# testing model on target domains

def evaluate_tgt(encoder, classifier, dataloader):
    """Evaluate the network on current target domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    
    with torch.no_grad():
        for batch_idx, (x, y) in enumerate(dataloader): # target dataloader
            if(train_on_gpu):
                x, y = x.to(device), y.to(device)

            pred_tgt = classifier(encoder(x))
            loss_tgt = criterion(pred_tgt, y)
            
            # append loss for each batch
            losses.append(loss_tgt.detach().item()) # detach the loss from compute graph 
            accuracies.append(y.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %% [markdown]
# ### Pre-training

# %%
# pre-training
encoder_src, classifier = train_src(encoder_src, classifier)
torch.save(encoder_src.state_dict(), './dump/source_encoder_cwru_cua_adda.pt')
torch.save(classifier.state_dict(), './dump/classifier_cwru_cua_adda.pt')
# encoder_src.load_state_dict(torch.load('./dump/source_encoder_cwru_cua_adda.pt'))
# classifier.load_state_dict(torch.load('./dump/classifier_cwru_cua_adda.pt'))
# Out:
# Epoch: 1
#  	 Train Loss:2.26 	 Train Acc:0.16
# 	 Val Loss:2.10 		 Val Acc:0.23
# Epoch: 2
#  	 Train Loss:1.90 	 Train Acc:0.27
# 	 Val Loss:1.71 		 Val Acc:0.33
# Epoch: 3
#  	 Train Loss:1.48 	 Train Acc:0.54
# 	 Val Loss:1.24 		 Val Acc:0.63
# Epoch: 4
#  	 Train Loss:1.04 	 Train Acc:0.71
# 	 Val Loss:0.90 		 Val Acc:0.83
# Epoch: 5
#  	 Train Loss:0.74 	 Train Acc:0.82
# 	 Val Loss:0.64 		 Val Acc:0.90
# Epoch: 6
#  	 Train Loss:0.52 	 Train Acc:0.89
# 	 Val Loss:0.44 		 Val Acc:0.90
# Epoch: 7
#  	 Train Loss:0.37 	 Train Acc:0.91
# 	 Val Loss:0.33 		 Val Acc:0.93
# Epoch: 8
#  	 Train Loss:0.28 	 Train Acc:0.93
# 	 Val Loss:0.24 		 Val Acc:0.94
# Epoch: 9
#  	 Train Loss:0.21 	 Train Acc:0.94
# 	 Val Loss:0.19 		 Val Acc:0.94
# Epoch: 10
#  	 Train Loss:0.16 	 Train Acc:0.95
# 	 Val Loss:0.15 		 Val Acc:0.95
# Epoch: 11
#  	 Train Loss:0.13 	 Train Acc:0.95
# 	 Val Loss:0.14 		 Val Acc:0.98
# Epoch: 12
#  	 Train Loss:0.11 	 Train Acc:0.96
# 	 Val Loss:0.10 		 Val Acc:0.96
# Epoch: 13
#  	 Train Loss:0.10 	 Train Acc:0.96
# 	 Val Loss:0.09 		 Val Acc:0.98
# Epoch: 14
#  	 Train Loss:0.08 	 Train Acc:0.97
# 	 Val Loss:0.08 		 Val Acc:0.99
# Epoch: 15
#  	 Train Loss:0.07 	 Train Acc:0.98
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 16
#  	 Train Loss:0.07 	 Train Acc:0.98
# 	 Val Loss:0.05 		 Val Acc:0.98
# Epoch: 17
#  	 Train Loss:0.06 	 Train Acc:0.98
# 	 Val Loss:0.04 		 Val Acc:0.99
# Epoch: 18
#  	 Train Loss:0.05 	 Train Acc:0.99
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 19
#  	 Train Loss:0.05 	 Train Acc:0.99
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 20
#  	 Train Loss:0.05 	 Train Acc:0.98
# 	 Val Loss:0.04 		 Val Acc:0.99
# Epoch: 21
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.03 		 Val Acc:0.99
# Epoch: 22
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.03 		 Val Acc:0.99
# Epoch: 23
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 24
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 25
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 26
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.07 		 Val Acc:0.98
# Epoch: 27
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:1.00
# Epoch: 28
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.03 		 Val Acc:0.99
# Epoch: 29
#  	 Train Loss:0.02 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99
# Epoch: 30
#  	 Train Loss:0.03 	 Train Acc:0.99
# 	 Val Loss:0.02 		 Val Acc:0.99

# %%
encoder_tgt.load_state_dict(encoder_src.state_dict())

# adaptation
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    encoder_tgt = train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase)
    
    print('\nTesting Accuracy on Previously Seen and Current Domains:')
    print(f'Source Domain {source_domain}:')
    src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
    print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
    for p in range(phase + 1):
        print(f'Target Domain {target_domains[p]}:')
        tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[p])
        print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# Phase 1 (Domain A to Domain B)
# Epoch: 1
#  	 Train (with Adv) Loss:0.62 	 Train Acc:0.80
# 	 Discriminator Loss:1.24 	 Discriminator Acc:0.27
# 	 Val (with Target) Loss:7.34 	 Val (with Target) Acc:0.42
# Epoch: 2
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.73
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:2.04 	 Val (with Target) Acc:0.72
# Epoch: 3
#  	 Train (with Adv) Loss:0.69 	 Train Acc:0.72
# 	 Discriminator Loss:0.82 	 Discriminator Acc:0.42
# 	 Val (with Target) Loss:0.86 	 Val (with Target) Acc:0.83
# Epoch: 4
#  	 Train (with Adv) Loss:0.73 	 Train Acc:0.71
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:2.60 	 Val (with Target) Acc:0.71
# Epoch: 5
#  	 Train (with Adv) Loss:0.73 	 Train Acc:0.73
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.58 	 Val (with Target) Acc:0.81
# Epoch: 6
#  	 Train (with Adv) Loss:0.73 	 Train Acc:0.70
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:2.80 	 Val (with Target) Acc:0.67
# Epoch: 7
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.80
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:1.46 	 Val (with Target) Acc:0.76
# Epoch: 8
#  	 Train (with Adv) Loss:0.75 	 Train Acc:0.76
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:2.13 	 Val (with Target) Acc:0.64
# Epoch: 9
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.72
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.92 	 Val (with Target) Acc:0.73
# Epoch: 10
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.78
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:1.83 	 Val (with Target) Acc:0.68
# Epoch: 11
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.72
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.25 	 Val (with Target) Acc:0.89
# Epoch: 12
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.74
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:1.65 	 Val (with Target) Acc:0.70
# Epoch: 13
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.81
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:1.59 	 Val (with Target) Acc:0.67
# Epoch: 14
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.72
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:2.83 	 Val (with Target) Acc:0.74
# Epoch: 15
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.76
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:1.76 	 Val (with Target) Acc:0.74
# Epoch: 16
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.81
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.84
# Epoch: 17
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.79
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:1.23 	 Val (with Target) Acc:0.76
# Epoch: 18
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.76
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.99 	 Val (with Target) Acc:0.85
# Epoch: 19
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.74
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.84 	 Val (with Target) Acc:0.71
# Epoch: 20
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.74
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:1.94 	 Val (with Target) Acc:0.68
# Epoch: 21
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.81
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.20 	 Val (with Target) Acc:0.94
# Epoch: 22
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.79
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:1.36 	 Val (with Target) Acc:0.74
# Epoch: 23
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.77
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.75 	 Val (with Target) Acc:0.83
# Epoch: 24
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.87
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.99 	 Val (with Target) Acc:0.78
# Epoch: 25
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.84
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.84
# Epoch: 26
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.81
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.17 	 Val (with Target) Acc:0.94
# Epoch: 27
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.85
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.21 	 Val (with Target) Acc:0.93
# Epoch: 28
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.85
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.31 	 Val (with Target) Acc:0.87
# Epoch: 29
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.86
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.13 	 Val (with Target) Acc:0.96
# Epoch: 30
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.84
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.83
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.14 	 Test (with Source) Acc:0.95
# Target Domain B:
# 	 Test (with Target) Loss:0.43 	 Test (with Target) Acc:0.85
#
# Phase 2 (Domain B to Domain C)
# Epoch: 1
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.82
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:2.16 	 Val (with Target) Acc:0.59
# Epoch: 2
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.82
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.48 	 Val (with Target) Acc:0.84
# Epoch: 3
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.78
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.94 	 Val (with Target) Acc:0.78
# Epoch: 4
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.81
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.86 	 Val (with Target) Acc:0.71
# Epoch: 5
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.86
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.25 	 Val (with Target) Acc:0.91
# Epoch: 6
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.87
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.91
# Epoch: 7
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.88
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.85
# Epoch: 8
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.85
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:1.44 	 Val (with Target) Acc:0.79
# Epoch: 9
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.80
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.87
# Epoch: 10
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.79
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.63 	 Val (with Target) Acc:0.84
# Epoch: 11
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.85
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.22 	 Val (with Target) Acc:0.92
# Epoch: 12
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.84
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:2.48 	 Val (with Target) Acc:0.67
# Epoch: 13
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.82
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.29 	 Val (with Target) Acc:0.90
# Epoch: 14
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.87
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.21 	 Val (with Target) Acc:0.93
# Epoch: 15
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.89
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:1.19 	 Val (with Target) Acc:0.82
# Epoch: 16
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.85
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.86 	 Val (with Target) Acc:0.87
# Epoch: 17
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.87
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.23 	 Val (with Target) Acc:0.91
# Epoch: 18
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.81
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.76 	 Val (with Target) Acc:0.76
# Epoch: 19
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.82
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.78 	 Val (with Target) Acc:0.82
# Epoch: 20
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.87
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.26 	 Val (with Target) Acc:0.90
# Epoch: 21
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.87
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.51 	 Val (with Target) Acc:0.88
# Epoch: 22
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.83
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.23 	 Val (with Target) Acc:0.93
# Epoch: 23
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.89
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:1.29 	 Val (with Target) Acc:0.72
# Epoch: 24
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.85
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.30 	 Val (with Target) Acc:0.90
# Epoch: 25
#  	 Train (with Adv) Loss:0.90 	 Train Acc:0.82
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.35 	 Val (with Target) Acc:0.89
# Epoch: 26
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.84
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.52 	 Val (with Target) Acc:0.86
# Epoch: 27
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.81
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.15 	 Val (with Target) Acc:0.94
# Epoch: 28
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.88
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.93 	 Val (with Target) Acc:0.81
# Epoch: 29
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.82
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.55 	 Val (with Target) Acc:0.86
# Epoch: 30
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.86
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.35 	 Val (with Target) Acc:0.89
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.12 	 Test (with Source) Acc:0.96
# Target Domain B:
# 	 Test (with Target) Loss:0.35 	 Test (with Target) Acc:0.85
# Target Domain C:
# 	 Test (with Target) Loss:0.29 	 Test (with Target) Acc:0.91
#
# Phase 3 (Domain C to Domain D)
# Epoch: 1
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.88
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.97 	 Val (with Target) Acc:0.77
# Epoch: 2
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.83
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.20 	 Val (with Target) Acc:0.95
# Epoch: 3
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.89
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.74 	 Val (with Target) Acc:0.80
# Epoch: 4
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.86
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.29 	 Val (with Target) Acc:0.91
# Epoch: 5
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.88
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.28 	 Val (with Target) Acc:0.94
# Epoch: 6
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.87
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:1.84 	 Val (with Target) Acc:0.69
# Epoch: 7
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.88
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.21 	 Val (with Target) Acc:0.93
# Epoch: 8
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.91
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.30 	 Val (with Target) Acc:0.89
# Epoch: 9
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.88
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.41 	 Val (with Target) Acc:0.87
# Epoch: 10
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.86
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.54 	 Val (with Target) Acc:0.83
# Epoch: 11
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.88
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.31 	 Val (with Target) Acc:0.91
# Epoch: 12
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.84
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.32 	 Val (with Target) Acc:0.90
# Epoch: 13
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.90
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.43 	 Val (with Target) Acc:0.87
# Epoch: 14
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.89
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.23 	 Val (with Target) Acc:0.96
# Epoch: 15
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.87
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.30 	 Val (with Target) Acc:0.89
# Epoch: 16
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.86
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.56 	 Val (with Target) Acc:0.79
# Epoch: 17
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.86
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.34 	 Val (with Target) Acc:0.87
# Epoch: 18
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.90
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.57 	 Val (with Target) Acc:0.82
# Epoch: 19
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.83
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.90
# Epoch: 20
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.83
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:2.73 	 Val (with Target) Acc:0.81
# Epoch: 21
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.80
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.88 	 Val (with Target) Acc:0.83
# Epoch: 22
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.89
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.47
# 	 Val (with Target) Loss:0.54 	 Val (with Target) Acc:0.82
# Epoch: 23
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.89
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:1.31 	 Val (with Target) Acc:0.73
# Epoch: 24
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.82
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:1.54 	 Val (with Target) Acc:0.81
# Epoch: 25
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.85
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.88
# Epoch: 26
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.87
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.85
# Epoch: 27
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.91
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.94 	 Val (with Target) Acc:0.83
# Epoch: 28
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.86
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.85
# Epoch: 29
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.88
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.47
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.81
# Epoch: 30
#  	 Train (with Adv) Loss:0.88 	 Train Acc:0.83
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.44 	 Val (with Target) Acc:0.86
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.22 	 Test (with Source) Acc:0.94
# Target Domain B:
# 	 Test (with Target) Loss:0.88 	 Test (with Target) Acc:0.76
# Target Domain C:
# 	 Test (with Target) Loss:1.02 	 Test (with Target) Acc:0.81
# Target Domain D:
# 	 Test (with Target) Loss:0.41 	 Test (with Target) Acc:0.84
#
# Phase 4 (Domain D to Domain E)
# Epoch: 1
#  	 Train (with Adv) Loss:0.90 	 Train Acc:0.20
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:37.85 	 Val (with Target) Acc:0.19
# Epoch: 2
#  	 Train (with Adv) Loss:0.90 	 Train Acc:0.18
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:37.09 	 Val (with Target) Acc:0.20
# Epoch: 3
#  	 Train (with Adv) Loss:0.93 	 Train Acc:0.21
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:37.69 	 Val (with Target) Acc:0.18
# Epoch: 4
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.23
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:36.18 	 Val (with Target) Acc:0.21
# Epoch: 5
#  	 Train (with Adv) Loss:0.91 	 Train Acc:0.22
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:39.36 	 Val (with Target) Acc:0.23
# Epoch: 6
#  	 Train (with Adv) Loss:0.90 	 Train Acc:0.22
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:42.68 	 Val (with Target) Acc:0.20
# Epoch: 7
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.21
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:43.22 	 Val (with Target) Acc:0.23
# Epoch: 8
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.22
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:44.97 	 Val (with Target) Acc:0.26
# Epoch: 9
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.23
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:47.09 	 Val (with Target) Acc:0.26
# Epoch: 10
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.22
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:44.99 	 Val (with Target) Acc:0.22
# Epoch: 11
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.22
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:46.15 	 Val (with Target) Acc:0.26
# Epoch: 12
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.23
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:47.42 	 Val (with Target) Acc:0.25
# Epoch: 13
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.22
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:45.60 	 Val (with Target) Acc:0.25
# Epoch: 14
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.23
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:44.98 	 Val (with Target) Acc:0.23
# Epoch: 15
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.22
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:45.93 	 Val (with Target) Acc:0.24
# Epoch: 16
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.23
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:45.56 	 Val (with Target) Acc:0.25
# Epoch: 17
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.23
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:45.06 	 Val (with Target) Acc:0.25
# Epoch: 18
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.23
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:44.21 	 Val (with Target) Acc:0.25
# Epoch: 19
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.24
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:46.54 	 Val (with Target) Acc:0.25
# Epoch: 20
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.23
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:45.72 	 Val (with Target) Acc:0.24
# Epoch: 21
#  	 Train (with Adv) Loss:0.94 	 Train Acc:0.24
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:46.69 	 Val (with Target) Acc:0.27
# Epoch: 22
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.24
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:45.11 	 Val (with Target) Acc:0.24
# Epoch: 23
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.24
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:45.34 	 Val (with Target) Acc:0.27
# Epoch: 24
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.24
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:44.34 	 Val (with Target) Acc:0.26
# Epoch: 25
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.24
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:45.83 	 Val (with Target) Acc:0.24
# Epoch: 26
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.24
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:46.34 	 Val (with Target) Acc:0.24
# Epoch: 27
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.23
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:46.21 	 Val (with Target) Acc:0.24
# Epoch: 28
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.24
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:46.22 	 Val (with Target) Acc:0.26
# Epoch: 29
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.24
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:43.19 	 Val (with Target) Acc:0.25
# Epoch: 30
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.24
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:43.97 	 Val (with Target) Acc:0.26
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:2.87 	 Test (with Source) Acc:0.51
# Target Domain B:
# 	 Test (with Target) Loss:2.96 	 Test (with Target) Acc:0.47
# Target Domain C:
# 	 Test (with Target) Loss:3.95 	 Test (with Target) Acc:0.44
# Target Domain D:
# 	 Test (with Target) Loss:2.59 	 Test (with Target) Acc:0.47
# Target Domain E:
# 	 Test (with Target) Loss:48.71 	 Test (with Target) Acc:0.23
#
# Phase 5 (Domain E to Domain F)
# Epoch: 1
#  	 Train (with Adv) Loss:1.03 	 Train Acc:0.22
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:54.14 	 Val (with Target) Acc:0.22
# Epoch: 2
#  	 Train (with Adv) Loss:1.05 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:56.52 	 Val (with Target) Acc:0.23
# Epoch: 3
#  	 Train (with Adv) Loss:1.03 	 Train Acc:0.21
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:60.99 	 Val (with Target) Acc:0.22
# Epoch: 4
#  	 Train (with Adv) Loss:1.05 	 Train Acc:0.20
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:68.35 	 Val (with Target) Acc:0.22
# Epoch: 5
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.20
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:70.97 	 Val (with Target) Acc:0.22
# Epoch: 6
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.20
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:73.75 	 Val (with Target) Acc:0.21
# Epoch: 7
#  	 Train (with Adv) Loss:1.10 	 Train Acc:0.20
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:79.28 	 Val (with Target) Acc:0.21
# Epoch: 8
#  	 Train (with Adv) Loss:1.06 	 Train Acc:0.20
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:82.19 	 Val (with Target) Acc:0.21
# Epoch: 9
#  	 Train (with Adv) Loss:1.09 	 Train Acc:0.19
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:82.46 	 Val (with Target) Acc:0.20
# Epoch: 10
#  	 Train (with Adv) Loss:1.07 	 Train Acc:0.19
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:87.71 	 Val (with Target) Acc:0.21
# Epoch: 11
#  	 Train (with Adv) Loss:1.07 	 Train Acc:0.20
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:86.11 	 Val (with Target) Acc:0.21
# Epoch: 12
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.19
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:87.39 	 Val (with Target) Acc:0.20
# Epoch: 13
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:93.56 	 Val (with Target) Acc:0.21
# Epoch: 14
#  	 Train (with Adv) Loss:1.09 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:95.56 	 Val (with Target) Acc:0.21
# Epoch: 15
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.20
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:96.17 	 Val (with Target) Acc:0.21
# Epoch: 16
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:95.16 	 Val (with Target) Acc:0.21
# Epoch: 17
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:94.70 	 Val (with Target) Acc:0.21
# Epoch: 18
#  	 Train (with Adv) Loss:1.05 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:96.96 	 Val (with Target) Acc:0.21
# Epoch: 19
#  	 Train (with Adv) Loss:1.07 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:98.35 	 Val (with Target) Acc:0.21
# Epoch: 20
#  	 Train (with Adv) Loss:1.06 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:98.56 	 Val (with Target) Acc:0.22
# Epoch: 21
#  	 Train (with Adv) Loss:1.07 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:100.05 	 Val (with Target) Acc:0.21
# Epoch: 22
#  	 Train (with Adv) Loss:1.07 	 Train Acc:0.20
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:97.47 	 Val (with Target) Acc:0.21
# Epoch: 23
#  	 Train (with Adv) Loss:1.06 	 Train Acc:0.19
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:101.64 	 Val (with Target) Acc:0.21
# Epoch: 24
#  	 Train (with Adv) Loss:1.06 	 Train Acc:0.20
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:102.22 	 Val (with Target) Acc:0.21
# Epoch: 25
#  	 Train (with Adv) Loss:1.10 	 Train Acc:0.19
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:103.12 	 Val (with Target) Acc:0.21
# Epoch: 26
#  	 Train (with Adv) Loss:1.11 	 Train Acc:0.20
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:103.28 	 Val (with Target) Acc:0.22
# Epoch: 27
#  	 Train (with Adv) Loss:1.09 	 Train Acc:0.20
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:99.97 	 Val (with Target) Acc:0.22
# Epoch: 28
#  	 Train (with Adv) Loss:1.07 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:100.81 	 Val (with Target) Acc:0.21
# Epoch: 29
#  	 Train (with Adv) Loss:1.08 	 Train Acc:0.19
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:101.87 	 Val (with Target) Acc:0.21
# Epoch: 30
#  	 Train (with Adv) Loss:1.11 	 Train Acc:0.19
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:100.84 	 Val (with Target) Acc:0.21
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:5.62 	 Test (with Source) Acc:0.59
# Target Domain B:
# 	 Test (with Target) Loss:5.73 	 Test (with Target) Acc:0.56
# Target Domain C:
# 	 Test (with Target) Loss:6.37 	 Test (with Target) Acc:0.52
# Target Domain D:
# 	 Test (with Target) Loss:4.61 	 Test (with Target) Acc:0.59
# Target Domain E:
# 	 Test (with Target) Loss:94.69 	 Test (with Target) Acc:0.23
# Target Domain F:
# 	 Test (with Target) Loss:125.60 	 Test (with Target) Acc:0.17
#
# Phase 6 (Domain F to Domain G)
# Epoch: 1
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.18
# 	 Discriminator Loss:0.47 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:50.74 	 Val (with Target) Acc:0.18
# Epoch: 2
#  	 Train (with Adv) Loss:1.16 	 Train Acc:0.17
# 	 Discriminator Loss:0.48 	 Discriminator Acc:0.78
# 	 Val (with Target) Loss:48.07 	 Val (with Target) Acc:0.23
# Epoch: 3
#  	 Train (with Adv) Loss:1.16 	 Train Acc:0.21
# 	 Discriminator Loss:0.47 	 Discriminator Acc:0.80
# 	 Val (with Target) Loss:45.42 	 Val (with Target) Acc:0.23
# Epoch: 4
#  	 Train (with Adv) Loss:1.16 	 Train Acc:0.20
# 	 Discriminator Loss:0.48 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:50.14 	 Val (with Target) Acc:0.23
# Epoch: 5
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.20
# 	 Discriminator Loss:0.48 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:50.78 	 Val (with Target) Acc:0.23
# Epoch: 6
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.21
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.76
# 	 Val (with Target) Loss:52.28 	 Val (with Target) Acc:0.23
# Epoch: 7
#  	 Train (with Adv) Loss:1.24 	 Train Acc:0.21
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:53.28 	 Val (with Target) Acc:0.23
# Epoch: 8
#  	 Train (with Adv) Loss:1.24 	 Train Acc:0.20
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:52.44 	 Val (with Target) Acc:0.20
# Epoch: 9
#  	 Train (with Adv) Loss:1.27 	 Train Acc:0.19
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:56.77 	 Val (with Target) Acc:0.22
# Epoch: 10
#  	 Train (with Adv) Loss:1.26 	 Train Acc:0.20
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:55.85 	 Val (with Target) Acc:0.22
# Epoch: 11
#  	 Train (with Adv) Loss:1.26 	 Train Acc:0.19
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:56.15 	 Val (with Target) Acc:0.19
# Epoch: 12
#  	 Train (with Adv) Loss:1.27 	 Train Acc:0.18
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:56.01 	 Val (with Target) Acc:0.20
# Epoch: 13
#  	 Train (with Adv) Loss:1.27 	 Train Acc:0.20
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:55.51 	 Val (with Target) Acc:0.23
# Epoch: 14
#  	 Train (with Adv) Loss:1.28 	 Train Acc:0.20
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:54.20 	 Val (with Target) Acc:0.19
# Epoch: 15
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.18
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:57.48 	 Val (with Target) Acc:0.20
# Epoch: 16
#  	 Train (with Adv) Loss:1.26 	 Train Acc:0.18
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:56.38 	 Val (with Target) Acc:0.19
# Epoch: 17
#  	 Train (with Adv) Loss:1.24 	 Train Acc:0.19
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:56.32 	 Val (with Target) Acc:0.20
# Epoch: 18
#  	 Train (with Adv) Loss:1.27 	 Train Acc:0.20
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:56.01 	 Val (with Target) Acc:0.20
# Epoch: 19
#  	 Train (with Adv) Loss:1.27 	 Train Acc:0.19
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:55.33 	 Val (with Target) Acc:0.21
# Epoch: 20
#  	 Train (with Adv) Loss:1.24 	 Train Acc:0.20
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:54.05 	 Val (with Target) Acc:0.20
# Epoch: 21
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.20
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:55.68 	 Val (with Target) Acc:0.22
# Epoch: 22
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.20
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:53.89 	 Val (with Target) Acc:0.20
# Epoch: 23
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.20
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:54.85 	 Val (with Target) Acc:0.22
# Epoch: 24
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.20
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:53.79 	 Val (with Target) Acc:0.21
# Epoch: 25
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.19
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:54.27 	 Val (with Target) Acc:0.20
# Epoch: 26
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.19
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:55.00 	 Val (with Target) Acc:0.22
# Epoch: 27
#  	 Train (with Adv) Loss:1.24 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:54.59 	 Val (with Target) Acc:0.22
# Epoch: 28
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.20
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:54.01 	 Val (with Target) Acc:0.20
# Epoch: 29
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.19
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:54.47 	 Val (with Target) Acc:0.20
# Epoch: 30
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.20
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:53.89 	 Val (with Target) Acc:0.22
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:7.97 	 Test (with Source) Acc:0.59
# Target Domain B:
# 	 Test (with Target) Loss:6.20 	 Test (with Target) Acc:0.46
# Target Domain C:
# 	 Test (with Target) Loss:5.39 	 Test (with Target) Acc:0.47
# Target Domain D:
# 	 Test (with Target) Loss:5.29 	 Test (with Target) Acc:0.52
# Target Domain E:
# 	 Test (with Target) Loss:73.78 	 Test (with Target) Acc:0.17
# Target Domain F:
# 	 Test (with Target) Loss:87.30 	 Test (with Target) Acc:0.17
# Target Domain G:
# 	 Test (with Target) Loss:60.23 	 Test (with Target) Acc:0.19
#
# Phase 7 (Domain G to Domain H)
# Epoch: 1
#  	 Train (with Adv) Loss:1.38 	 Train Acc:0.21
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:59.39 	 Val (with Target) Acc:0.23
# Epoch: 2
#  	 Train (with Adv) Loss:1.33 	 Train Acc:0.21
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:58.21 	 Val (with Target) Acc:0.23
# Epoch: 3
#  	 Train (with Adv) Loss:1.29 	 Train Acc:0.21
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:57.47 	 Val (with Target) Acc:0.23
# Epoch: 4
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.21
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:58.57 	 Val (with Target) Acc:0.23
# Epoch: 5
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.21
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:56.69 	 Val (with Target) Acc:0.23
# Epoch: 6
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.21
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:56.44 	 Val (with Target) Acc:0.23
# Epoch: 7
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:56.61 	 Val (with Target) Acc:0.23
# Epoch: 8
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.21
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:55.47 	 Val (with Target) Acc:0.23
# Epoch: 9
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.22
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:56.31 	 Val (with Target) Acc:0.23
# Epoch: 10
#  	 Train (with Adv) Loss:1.24 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:56.60 	 Val (with Target) Acc:0.23
# Epoch: 11
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:57.91 	 Val (with Target) Acc:0.23
# Epoch: 12
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:57.18 	 Val (with Target) Acc:0.23
# Epoch: 13
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.21
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:55.62 	 Val (with Target) Acc:0.23
# Epoch: 14
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:56.15 	 Val (with Target) Acc:0.23
# Epoch: 15
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.21
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:57.97 	 Val (with Target) Acc:0.22
# Epoch: 16
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.21
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:57.68 	 Val (with Target) Acc:0.23
# Epoch: 17
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.21
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:57.06 	 Val (with Target) Acc:0.23
# Epoch: 18
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:56.29 	 Val (with Target) Acc:0.24
# Epoch: 19
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:57.48 	 Val (with Target) Acc:0.23
# Epoch: 20
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:57.08 	 Val (with Target) Acc:0.23
# Epoch: 21
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.21
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:55.54 	 Val (with Target) Acc:0.24
# Epoch: 22
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:57.00 	 Val (with Target) Acc:0.24
# Epoch: 23
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.22
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:56.59 	 Val (with Target) Acc:0.24
# Epoch: 24
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.22
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:58.09 	 Val (with Target) Acc:0.23
# Epoch: 25
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:58.74 	 Val (with Target) Acc:0.23
# Epoch: 26
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:60.29 	 Val (with Target) Acc:0.23
# Epoch: 27
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:54.81 	 Val (with Target) Acc:0.25
# Epoch: 28
#  	 Train (with Adv) Loss:1.17 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:55.66 	 Val (with Target) Acc:0.23
# Epoch: 29
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:56.46 	 Val (with Target) Acc:0.22
# Epoch: 30
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.21
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:55.40 	 Val (with Target) Acc:0.23
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:16.62 	 Test (with Source) Acc:0.45
# Target Domain B:
# 	 Test (with Target) Loss:10.90 	 Test (with Target) Acc:0.35
# Target Domain C:
# 	 Test (with Target) Loss:10.81 	 Test (with Target) Acc:0.37
# Target Domain D:
# 	 Test (with Target) Loss:9.40 	 Test (with Target) Acc:0.41
# Target Domain E:
# 	 Test (with Target) Loss:68.17 	 Test (with Target) Acc:0.17
# Target Domain F:
# 	 Test (with Target) Loss:78.35 	 Test (with Target) Acc:0.18
# Target Domain G:
# 	 Test (with Target) Loss:54.55 	 Test (with Target) Acc:0.19
# Target Domain H:
# 	 Test (with Target) Loss:62.76 	 Test (with Target) Acc:0.19

# %%
generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_src, "cuda")
src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_tgt[phase], "cuda")
    tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[phase])
    print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# 	 Test (with Source) Loss:16.62 	 Test (with Source) Acc:0.45
#
# Phase 1 (Domain A to Domain B)
# 	 Test (with Target) Loss:10.90 	 Test (with Target) Acc:0.35
#
# Phase 2 (Domain B to Domain C)
# 	 Test (with Target) Loss:10.81 	 Test (with Target) Acc:0.37
#
# Phase 3 (Domain C to Domain D)
# 	 Test (with Target) Loss:9.40 	 Test (with Target) Acc:0.41
#
# Phase 4 (Domain D to Domain E)
# 	 Test (with Target) Loss:68.17 	 Test (with Target) Acc:0.17
#
# Phase 5 (Domain E to Domain F)
# 	 Test (with Target) Loss:78.35 	 Test (with Target) Acc:0.18
#
# Phase 6 (Domain F to Domain G)
# 	 Test (with Target) Loss:54.55 	 Test (with Target) Acc:0.19
#
# Phase 7 (Domain G to Domain H)
# 	 Test (with Target) Loss:62.76 	 Test (with Target) Acc:0.19

# %%
output = encoder_src(train_dataloader_tgt[5].dataset.data[5].to("cuda"))
plt.plot(output.detach().cpu()[0].numpy())

# %%
output2 = encoder_src(train_dataloader_tgt[0].dataset.data[5].to("cuda"))
plt.plot(output.detach().cpu()[0].numpy())

# %%
output = encoder_tgt(train_dataloader_tgt[5].dataset.data[5].to("cuda"))
plt.plot(output.detach().cpu()[0].numpy())

# %%
output = encoder_tgt(train_dataloader_tgt[0].dataset.data[5].to("cuda"))
plt.plot(output.detach().cpu()[0].numpy())
