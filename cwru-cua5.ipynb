# %% [markdown]
# ### Continuous Unsupervised Adaptation

# %%
# import modules and libraries
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable

# functions to create datasets and models
from data.data import *
from models.models import *

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available')
else:
    print('CUDA is available')
    device = torch.device('cuda')
# Out:
# CUDA is available

# %% [markdown]
# ### Parameters

# %%
"""Parameters for this experiment"""
# params for loading the data
path = 'data/CWRU/bearing/'
source_domain = 'E'
target_domains = ['F', 'G', 'H', 'A', 'B', 'C', 'D']

# params for configuring the model
input_dim = 1
hidden_dim = 256
output_dim = 10
drop_prob = 0.5

# params for training the model
epochs_pre = 30 # pre-training
epochs = 30

# optimizing the model
lr = 1e-4
d_lr = 1e-4
batch_size = 20
beta1 = 0.5
beta2 = 0.9
lambda_rpy = 0.03

# %% [markdown]
# ### Data Loading

# %%
# source domain data for training, validating and testing
train_dataloader_src, val_dataloader_src, test_dataloader_src = generate_dataloaders(path, source_domain, batch_size)

# target domain data for validating and testing
train_dataloader_tgt, val_dataloader_tgt, test_dataloader_tgt = [], [], []
for target_domain in target_domains:
    train_dataloader_temp, val_dataloader_temp, test_dataloader_temp = generate_dataloaders(path, target_domain, batch_size)
    
    train_dataloader_tgt.append(train_dataloader_temp)
    val_dataloader_tgt.append(val_dataloader_temp)
    test_dataloader_tgt.append(test_dataloader_temp)

# replay data for CDA
replay_dataset = ReplayDataset(train_dataloader_src.dataset)
replay_dataloader = DataLoader(dataset=replay_dataset, batch_size=batch_size)

# %% [markdown]
# ### Model

# %%
encoder_src = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim # hidden layers 64
)

classifier = Classifier_AMDA(
    hidden_dim=hidden_dim, # hidden layers 64
    output_dim=output_dim, # 3 classes (healthy, inner- and outer-bearing damages)
    dropout=drop_prob # dropout prob 0.5
)

encoder_tgt = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim, # hidden layers 64
)

discriminator = Discriminator(
    hidden_dim=hidden_dim
)

if train_on_gpu:
    encoder_src = encoder_src.to(device)
    classifier = classifier.to(device)
    encoder_tgt = encoder_tgt.to(device)
    discriminator = discriminator.to(device)

# %% [markdown]
# #### Functions for training and testing the model

# %%
# functions for training source encoder and shared classifier
def train_src(encoder, classifier):
    """Train the source encoder and shared classifier on source domain"""
    encoder.train()
    classifier.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        list(encoder.parameters()) + list(classifier.parameters()),
        lr=lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs_pre):
        accuracies = []
        losses = []

        for batch_idx, (x_src, y_src) in enumerate(train_dataloader_src):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            optimizer.zero_grad()

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            loss_src.backward()

            optimizer.step()

            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_src(encoder, classifier, phase = 'Val')
        print(f'\t Val Loss:{val_loss:0.2f} \t\t Val Acc:{val_acc:0.2f}')

    return encoder, classifier

# testing model on source domain
def evaluate_src(encoder, classifier, phase='Val'): # phase can be validate or test
    """Evaluate the trained network on source domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    dataloader = val_dataloader_src if phase == 'Val' else test_dataloader_src
    
    with torch.no_grad():
        for batch_idx, (x_src, y_src) in enumerate(dataloader):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            
            # append loss for each batch
            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# Continuous Unsupervised Adaptation (CUA)
# functions for training target encoder
def train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase):
    """Train the target encoder on target domains with source encoder and test the network"""
    encoder_tgt.train()
    discriminator.train()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        encoder_tgt.parameters(),
        lr=lr,
        betas=(beta1, beta2)
    )
    d_optimizer = Adam(
        discriminator.parameters(),
        lr=d_lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs):
        losses = []
        losses_d = []
        losses_tgt = []
        losses_rpy = []
        accuracies = []
        accuracies_d = []

        for batch_idx, ((x_src, y_src), (x_tgt, y_tgt), (x_rpy, y_rpy)) in enumerate(zip(train_dataloader_src, train_dataloader_tgt[phase], replay_dataloader)):
            if(train_on_gpu):
                x_src, y_src = x_src.to(device), y_src.to(device)
                x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)
                x_rpy, y_rpy = x_rpy.to(device), y_rpy.to(device)

            optimizer.zero_grad()
            d_optimizer.zero_grad()

            # part 1: sequential unsupervised adaptation
            # learn e_src and _tgt: source and target mapping represenations
            e_src = encoder_src(x_src)
            e_tgt = encoder_tgt(x_tgt)
            e_concat = torch.concat((e_src.detach(), e_tgt.detach()), 0)
            # minimize distance between source and target empirical mapping distribution using adversarial discriminator
            d_concat = discriminator(e_concat)

            label_src = Variable(torch.ones(e_src.size(0)).long()).to(device)
            label_tgt = Variable(torch.zeros(e_tgt.size(0)).long()).to(device)
            label_concat = torch.cat((label_src, label_tgt), 0)

            loss_d = criterion(d_concat, label_concat)
            loss_d.backward()
            d_optimizer.step()

            e_tgt = encoder_tgt(x_tgt)
            pred_tgt = classifier(e_tgt)
            d_tgt = discriminator(e_tgt)
            label_tgt = Variable(torch.ones(e_tgt.size(0)).long()).to(device)
            loss_tgt = criterion(d_tgt, label_tgt)

            # part 2: continuous replay adaptation
            # additional replay loss to retain 'prior knowledge'
            pred_rpy = classifier(encoder_tgt(x_rpy))
            loss_rpy = criterion(pred_rpy, y_rpy)
            loss = loss_tgt + lambda_rpy * loss_rpy
            loss.backward()

            optimizer.step()

            # training (with replay) losses and accuracies
            losses.append(loss.detach().item()) # detach the loss from compute graph
            losses_d.append(loss_d.detach().item())
            losses_tgt.append(loss_tgt.detach().item())
            losses_rpy.append(loss_rpy.detach().item())
            accuracies.append(y_tgt.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            accuracies_d.append(torch.squeeze(d_concat.max(1)[1]).eq(label_concat.detach()).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')
        print(f'\t Train (Adv) Loss:{torch.tensor(losses_tgt).mean():0.2f} \t Train (Replay) Loss:{torch.tensor(losses_rpy).mean():0.2f}')
        print(f'\t Discriminator Loss:{torch.tensor(losses_d).mean():0.2f} \t Discriminator Acc:{torch.tensor(accuracies_d).mean():0.2f}')
        
        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_tgt(encoder_tgt, classifier, val_dataloader_tgt[phase])
        print(f'\t Val (with Target) Loss:{val_loss:0.2f} \t Val (with Target) Acc:{val_acc:0.2f}')

    return encoder_tgt
    
# testing model on target domains
def evaluate_tgt(encoder, classifier, dataloader):
    """Evaluate the network on current target domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    
    with torch.no_grad():
        for batch_idx, (x, y) in enumerate(dataloader): # target dataloader
            if(train_on_gpu):
                x, y = x.to(device), y.to(device)

            pred_tgt = classifier(encoder(x))
            loss_tgt = criterion(pred_tgt, y)
            
            # append loss for each batch
            losses.append(loss_tgt.detach().item()) # detach the loss from compute graph 
            accuracies.append(y.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# subsample previously seen examples and their respective classification scores as 'soft labels' from the target domains
def generate_data_tuple(encoder_tgt, classifier, dataloader):
    print('===> generate new replay dataset!')
    encoder_tgt.eval()
    classifier.eval()

    all_x, all_pred = [], []
    for batch_idx, (x_tgt, y_tgt) in enumerate(dataloader):
        if(train_on_gpu):
            x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)

        # perform classification with the target mapping representations
        pred_tgt = classifier(encoder_tgt(x_tgt))

        all_x.append(to_np(x_tgt))
        all_pred.append(to_np(pred_tgt.detach().argmax(dim=1)))
        
    x, pred = np.concatenate(all_x, 0), np.concatenate(all_pred, 0)
    print('generated: ', x.shape, pred.shape)
    return x, pred

# %% [markdown]
# ### Pre-training

# %%
# pre-training
encoder_src, classifier = train_src(encoder_src, classifier)
torch.save(encoder_src.state_dict(), './dump/source_encoder_cwru_cua5.pt')
torch.save(classifier.state_dict(), './dump/classifier_cwru_cua5.pt')
# encoder_src.load_state_dict(torch.load('./dump/source_encoder_cwru_cua5.pt'))
# classifier.load_state_dict(torch.load('./dump/classifier_cwru_cua5.pt'))
src_test_loss, src_test_acc = evaluate_src(encoder_src, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}')
# Out:
# Epoch: 1
#  	 Train Loss:2.26 	 Train Acc:0.18
# 	 Val Loss:2.09 		 Val Acc:0.22
# Epoch: 2
#  	 Train Loss:1.92 	 Train Acc:0.21
# 	 Val Loss:1.73 		 Val Acc:0.28
# Epoch: 3
#  	 Train Loss:1.53 	 Train Acc:0.42
# 	 Val Loss:1.29 		 Val Acc:0.67
# Epoch: 4
#  	 Train Loss:1.14 	 Train Acc:0.66
# 	 Val Loss:0.99 		 Val Acc:0.75
# Epoch: 5
#  	 Train Loss:0.86 	 Train Acc:0.75
# 	 Val Loss:0.76 		 Val Acc:0.79
# Epoch: 6
#  	 Train Loss:0.68 	 Train Acc:0.79
# 	 Val Loss:0.61 		 Val Acc:0.81
# Epoch: 7
#  	 Train Loss:0.55 	 Train Acc:0.82
# 	 Val Loss:0.57 		 Val Acc:0.78
# Epoch: 8
#  	 Train Loss:0.47 	 Train Acc:0.83
# 	 Val Loss:0.44 		 Val Acc:0.84
# Epoch: 9
#  	 Train Loss:0.41 	 Train Acc:0.86
# 	 Val Loss:0.41 		 Val Acc:0.86
# Epoch: 10
#  	 Train Loss:0.36 	 Train Acc:0.88
# 	 Val Loss:0.36 		 Val Acc:0.87
# Epoch: 11
#  	 Train Loss:0.32 	 Train Acc:0.88
# 	 Val Loss:0.31 		 Val Acc:0.91
# Epoch: 12
#  	 Train Loss:0.29 	 Train Acc:0.90
# 	 Val Loss:0.28 		 Val Acc:0.91
# Epoch: 13
#  	 Train Loss:0.27 	 Train Acc:0.91
# 	 Val Loss:0.26 		 Val Acc:0.92
# Epoch: 14
#  	 Train Loss:0.25 	 Train Acc:0.91
# 	 Val Loss:0.24 		 Val Acc:0.92
# Epoch: 15
#  	 Train Loss:0.23 	 Train Acc:0.92
# 	 Val Loss:0.22 		 Val Acc:0.93
# Epoch: 16
#  	 Train Loss:0.21 	 Train Acc:0.92
# 	 Val Loss:0.21 		 Val Acc:0.93
# Epoch: 17
#  	 Train Loss:0.20 	 Train Acc:0.93
# 	 Val Loss:0.22 		 Val Acc:0.93
# Epoch: 18
#  	 Train Loss:0.19 	 Train Acc:0.93
# 	 Val Loss:0.20 		 Val Acc:0.93
# Epoch: 19
#  	 Train Loss:0.18 	 Train Acc:0.93
# 	 Val Loss:0.22 		 Val Acc:0.92
# Epoch: 20
#  	 Train Loss:0.18 	 Train Acc:0.93
# 	 Val Loss:0.24 		 Val Acc:0.91
# Epoch: 21
#  	 Train Loss:0.17 	 Train Acc:0.94
# 	 Val Loss:0.31 		 Val Acc:0.88
# Epoch: 22
#  	 Train Loss:0.16 	 Train Acc:0.94
# 	 Val Loss:0.18 		 Val Acc:0.95
# Epoch: 23
#  	 Train Loss:0.15 	 Train Acc:0.94
# 	 Val Loss:0.17 		 Val Acc:0.95
# Epoch: 24
#  	 Train Loss:0.15 	 Train Acc:0.95
# 	 Val Loss:0.16 		 Val Acc:0.94
# Epoch: 25
#  	 Train Loss:0.14 	 Train Acc:0.95
# 	 Val Loss:0.21 		 Val Acc:0.93
# Epoch: 26
#  	 Train Loss:0.14 	 Train Acc:0.95
# 	 Val Loss:0.17 		 Val Acc:0.95
# Epoch: 27
#  	 Train Loss:0.13 	 Train Acc:0.95
# 	 Val Loss:0.23 		 Val Acc:0.91
# Epoch: 28
#  	 Train Loss:0.13 	 Train Acc:0.95
# 	 Val Loss:0.16 		 Val Acc:0.94
# Epoch: 29
#  	 Train Loss:0.12 	 Train Acc:0.96
# 	 Val Loss:0.16 		 Val Acc:0.95
# Epoch: 30
#  	 Train Loss:0.12 	 Train Acc:0.96
# 	 Val Loss:0.14 		 Val Acc:0.95
# 	 Test (with Source) Loss:0.12 	 Test (with Source) Acc:0.96

# %%
encoder_tgt.load_state_dict(encoder_src.state_dict())

# adaptation
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    encoder_tgt = train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase)
    
    print('\nTesting Accuracy on Previously Seen and Current Domains:')
    print(f'Source Domain {source_domain}:')
    src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
    print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
    for p in range(phase + 1):
        print(f'Target Domain {target_domains[p]}:')
        tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[p])
        print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')

    # update replay data and dataloader
    data_tuple = generate_data_tuple(encoder_tgt, classifier, train_dataloader_tgt[phase])
    replay_dataset.replay_dataset.update(data_tuple)
    print(replay_dataset.__len__())
    replay_dataloader = DataLoader(dataset=replay_dataset, batch_size=batch_size)
# Out:
# Phase 1 (Domain E to Domain F)
# Epoch: 1
#  	 Train Loss:0.66 	 Train Acc:0.54
# 	 Train (Adv) Loss:0.65 	 Train (Replay) Loss:0.40
# 	 Discriminator Loss:0.79 	 Discriminator Acc:0.33
# 	 Val (with Target) Loss:8.23 	 Val (with Target) Acc:0.58
# Epoch: 2
#  	 Train Loss:0.77 	 Train Acc:0.51
# 	 Train (Adv) Loss:0.75 	 Train (Replay) Loss:0.39
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:8.69 	 Val (with Target) Acc:0.55
# Epoch: 3
#  	 Train Loss:0.77 	 Train Acc:0.53
# 	 Train (Adv) Loss:0.76 	 Train (Replay) Loss:0.36
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:8.09 	 Val (with Target) Acc:0.54
# Epoch: 4
#  	 Train Loss:0.79 	 Train Acc:0.53
# 	 Train (Adv) Loss:0.78 	 Train (Replay) Loss:0.37
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:9.92 	 Val (with Target) Acc:0.62
# Epoch: 5
#  	 Train Loss:0.80 	 Train Acc:0.55
# 	 Train (Adv) Loss:0.79 	 Train (Replay) Loss:0.39
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:8.46 	 Val (with Target) Acc:0.54
# Epoch: 6
#  	 Train Loss:0.81 	 Train Acc:0.56
# 	 Train (Adv) Loss:0.80 	 Train (Replay) Loss:0.29
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:9.32 	 Val (with Target) Acc:0.62
# Epoch: 7
#  	 Train Loss:0.82 	 Train Acc:0.59
# 	 Train (Adv) Loss:0.81 	 Train (Replay) Loss:0.40
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:7.92 	 Val (with Target) Acc:0.58
# Epoch: 8
#  	 Train Loss:0.83 	 Train Acc:0.57
# 	 Train (Adv) Loss:0.82 	 Train (Replay) Loss:0.34
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:8.04 	 Val (with Target) Acc:0.68
# Epoch: 9
#  	 Train Loss:0.82 	 Train Acc:0.56
# 	 Train (Adv) Loss:0.81 	 Train (Replay) Loss:0.34
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:9.59 	 Val (with Target) Acc:0.66
# Epoch: 10
#  	 Train Loss:0.85 	 Train Acc:0.63
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.28
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:7.89 	 Val (with Target) Acc:0.63
# Epoch: 11
#  	 Train Loss:0.84 	 Train Acc:0.63
# 	 Train (Adv) Loss:0.83 	 Train (Replay) Loss:0.24
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:7.77 	 Val (with Target) Acc:0.71
# Epoch: 12
#  	 Train Loss:0.85 	 Train Acc:0.62
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.36
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:8.28 	 Val (with Target) Acc:0.69
# Epoch: 13
#  	 Train Loss:0.85 	 Train Acc:0.66
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.29
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:10.40 	 Val (with Target) Acc:0.63
# Epoch: 14
#  	 Train Loss:0.86 	 Train Acc:0.66
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.29
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:7.31 	 Val (with Target) Acc:0.69
# Epoch: 15
#  	 Train Loss:0.86 	 Train Acc:0.67
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.33
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:7.30 	 Val (with Target) Acc:0.71
# Epoch: 16
#  	 Train Loss:0.86 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.33
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:9.23 	 Val (with Target) Acc:0.68
# Epoch: 17
#  	 Train Loss:0.86 	 Train Acc:0.67
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.36
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:7.44 	 Val (with Target) Acc:0.77
# Epoch: 18
#  	 Train Loss:0.86 	 Train Acc:0.70
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.41
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:7.56 	 Val (with Target) Acc:0.79
# Epoch: 19
#  	 Train Loss:0.87 	 Train Acc:0.71
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.36
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:7.89 	 Val (with Target) Acc:0.76
# Epoch: 20
#  	 Train Loss:0.87 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.39
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:9.17 	 Val (with Target) Acc:0.66
# Epoch: 21
#  	 Train Loss:0.88 	 Train Acc:0.66
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:7.99 	 Val (with Target) Acc:0.70
# Epoch: 22
#  	 Train Loss:0.88 	 Train Acc:0.70
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.41
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:10.57 	 Val (with Target) Acc:0.60
# Epoch: 23
#  	 Train Loss:0.88 	 Train Acc:0.70
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.43
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:8.66 	 Val (with Target) Acc:0.71
# Epoch: 24
#  	 Train Loss:0.87 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.43
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:9.00 	 Val (with Target) Acc:0.66
# Epoch: 25
#  	 Train Loss:0.88 	 Train Acc:0.66
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.47
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:8.31 	 Val (with Target) Acc:0.71
# Epoch: 26
#  	 Train Loss:0.88 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.42
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:9.11 	 Val (with Target) Acc:0.62
# Epoch: 27
#  	 Train Loss:0.88 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.47
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:7.54 	 Val (with Target) Acc:0.73
# Epoch: 28
#  	 Train Loss:0.89 	 Train Acc:0.67
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.53
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:7.93 	 Val (with Target) Acc:0.70
# Epoch: 29
#  	 Train Loss:0.88 	 Train Acc:0.66
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:8.71 	 Val (with Target) Acc:0.69
# Epoch: 30
#  	 Train Loss:0.89 	 Train Acc:0.65
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.55
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:8.25 	 Val (with Target) Acc:0.69
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:0.46 	 Test (with Source) Acc:0.82
# Target Domain F:
# 	 Test (with Target) Loss:7.41 	 Test (with Target) Acc:0.68
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 4800
#
# Phase 2 (Domain F to Domain G)
# Epoch: 1
#  	 Train Loss:0.92 	 Train Acc:0.61
# 	 Train (Adv) Loss:0.90 	 Train (Replay) Loss:0.57
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:10.46 	 Val (with Target) Acc:0.61
# Epoch: 2
#  	 Train Loss:0.92 	 Train Acc:0.62
# 	 Train (Adv) Loss:0.91 	 Train (Replay) Loss:0.62
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.08 	 Val (with Target) Acc:0.62
# Epoch: 3
#  	 Train Loss:0.91 	 Train Acc:0.64
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.58
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:9.09 	 Val (with Target) Acc:0.69
# Epoch: 4
#  	 Train Loss:0.93 	 Train Acc:0.65
# 	 Train (Adv) Loss:0.91 	 Train (Replay) Loss:0.68
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:11.50 	 Val (with Target) Acc:0.52
# Epoch: 5
#  	 Train Loss:0.94 	 Train Acc:0.66
# 	 Train (Adv) Loss:0.92 	 Train (Replay) Loss:0.64
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:8.74 	 Val (with Target) Acc:0.74
# Epoch: 6
#  	 Train Loss:0.95 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.93 	 Train (Replay) Loss:0.71
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:12.65 	 Val (with Target) Acc:0.44
# Epoch: 7
#  	 Train Loss:0.96 	 Train Acc:0.63
# 	 Train (Adv) Loss:0.93 	 Train (Replay) Loss:0.83
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:9.51 	 Val (with Target) Acc:0.67
# Epoch: 8
#  	 Train Loss:0.99 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.97 	 Train (Replay) Loss:0.69
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.63 	 Val (with Target) Acc:0.68
# Epoch: 9
#  	 Train Loss:1.00 	 Train Acc:0.68
# 	 Train (Adv) Loss:0.97 	 Train (Replay) Loss:0.78
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.12 	 Val (with Target) Acc:0.75
# Epoch: 10
#  	 Train Loss:1.02 	 Train Acc:0.62
# 	 Train (Adv) Loss:0.99 	 Train (Replay) Loss:1.05
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:13.32 	 Val (with Target) Acc:0.41
# Epoch: 11
#  	 Train Loss:1.00 	 Train Acc:0.71
# 	 Train (Adv) Loss:0.98 	 Train (Replay) Loss:0.79
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:9.70 	 Val (with Target) Acc:0.74
# Epoch: 12
#  	 Train Loss:1.03 	 Train Acc:0.70
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:0.78
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:9.34 	 Val (with Target) Acc:0.71
# Epoch: 13
#  	 Train Loss:1.04 	 Train Acc:0.70
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:0.84
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.23 	 Val (with Target) Acc:0.74
# Epoch: 14
#  	 Train Loss:1.04 	 Train Acc:0.71
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:0.85
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:11.04 	 Val (with Target) Acc:0.68
# Epoch: 15
#  	 Train Loss:1.04 	 Train Acc:0.71
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:0.82
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.69 	 Val (with Target) Acc:0.74
# Epoch: 16
#  	 Train Loss:1.07 	 Train Acc:0.64
# 	 Train (Adv) Loss:1.03 	 Train (Replay) Loss:1.30
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:9.12 	 Val (with Target) Acc:0.73
# Epoch: 17
#  	 Train Loss:1.04 	 Train Acc:0.71
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:0.95
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.86 	 Val (with Target) Acc:0.73
# Epoch: 18
#  	 Train Loss:1.05 	 Train Acc:0.68
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:1.23
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:10.29 	 Val (with Target) Acc:0.69
# Epoch: 19
#  	 Train Loss:1.06 	 Train Acc:0.69
# 	 Train (Adv) Loss:1.03 	 Train (Replay) Loss:0.98
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.20 	 Val (with Target) Acc:0.70
# Epoch: 20
#  	 Train Loss:1.08 	 Train Acc:0.69
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:0.97
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.81 	 Val (with Target) Acc:0.69
# Epoch: 21
#  	 Train Loss:1.07 	 Train Acc:0.71
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.99
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:9.06 	 Val (with Target) Acc:0.52
# Epoch: 22
#  	 Train Loss:1.08 	 Train Acc:0.70
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:0.92
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.19 	 Val (with Target) Acc:0.71
# Epoch: 23
#  	 Train Loss:1.07 	 Train Acc:0.72
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.88
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:10.85 	 Val (with Target) Acc:0.68
# Epoch: 24
#  	 Train Loss:1.05 	 Train Acc:0.69
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.01
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.97 	 Val (with Target) Acc:0.72
# Epoch: 25
#  	 Train Loss:1.07 	 Train Acc:0.72
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.93
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:9.42 	 Val (with Target) Acc:0.76
# Epoch: 26
#  	 Train Loss:1.07 	 Train Acc:0.71
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.97
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:10.49 	 Val (with Target) Acc:0.73
# Epoch: 27
#  	 Train Loss:1.09 	 Train Acc:0.69
# 	 Train (Adv) Loss:1.06 	 Train (Replay) Loss:1.02
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:10.17 	 Val (with Target) Acc:0.67
# Epoch: 28
#  	 Train Loss:1.06 	 Train Acc:0.69
# 	 Train (Adv) Loss:1.03 	 Train (Replay) Loss:1.02
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.16 	 Val (with Target) Acc:0.69
# Epoch: 29
#  	 Train Loss:1.07 	 Train Acc:0.73
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.96
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:9.26 	 Val (with Target) Acc:0.74
# Epoch: 30
#  	 Train Loss:1.07 	 Train Acc:0.68
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.95
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:10.09 	 Val (with Target) Acc:0.71
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:1.20 	 Test (with Source) Acc:0.72
# Target Domain F:
# 	 Test (with Target) Loss:7.48 	 Test (with Target) Acc:0.64
# Target Domain G:
# 	 Test (with Target) Loss:8.93 	 Test (with Target) Acc:0.73
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 7200
#
# Phase 3 (Domain G to Domain H)
# Epoch: 1
#  	 Train Loss:1.05 	 Train Acc:0.60
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.02
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:11.06 	 Val (with Target) Acc:0.62
# Epoch: 2
#  	 Train Loss:1.01 	 Train Acc:0.54
# 	 Train (Adv) Loss:0.91 	 Train (Replay) Loss:3.33
# 	 Discriminator Loss:0.85 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:14.62 	 Val (with Target) Acc:0.45
# Epoch: 3
#  	 Train Loss:1.11 	 Train Acc:0.54
# 	 Train (Adv) Loss:1.06 	 Train (Replay) Loss:1.61
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:10.69 	 Val (with Target) Acc:0.59
# Epoch: 4
#  	 Train Loss:1.11 	 Train Acc:0.61
# 	 Train (Adv) Loss:1.08 	 Train (Replay) Loss:0.85
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:11.02 	 Val (with Target) Acc:0.63
# Epoch: 5
#  	 Train Loss:1.05 	 Train Acc:0.53
# 	 Train (Adv) Loss:0.97 	 Train (Replay) Loss:2.39
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:12.81 	 Val (with Target) Acc:0.59
# Epoch: 6
#  	 Train Loss:1.12 	 Train Acc:0.60
# 	 Train (Adv) Loss:1.10 	 Train (Replay) Loss:0.79
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.74 	 Val (with Target) Acc:0.60
# Epoch: 7
#  	 Train Loss:1.07 	 Train Acc:0.56
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.96
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.56 	 Val (with Target) Acc:0.63
# Epoch: 8
#  	 Train Loss:1.07 	 Train Acc:0.61
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.82
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:11.75 	 Val (with Target) Acc:0.58
# Epoch: 9
#  	 Train Loss:1.06 	 Train Acc:0.59
# 	 Train (Adv) Loss:1.03 	 Train (Replay) Loss:0.96
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:10.16 	 Val (with Target) Acc:0.61
# Epoch: 10
#  	 Train Loss:1.03 	 Train Acc:0.60
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:0.97
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:12.47 	 Val (with Target) Acc:0.49
# Epoch: 11
#  	 Train Loss:1.03 	 Train Acc:0.60
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:1.06
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:11.23 	 Val (with Target) Acc:0.59
# Epoch: 12
#  	 Train Loss:1.04 	 Train Acc:0.57
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:0.75
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:11.14 	 Val (with Target) Acc:0.59
# Epoch: 13
#  	 Train Loss:1.03 	 Train Acc:0.58
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:0.95
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:10.96 	 Val (with Target) Acc:0.61
# Epoch: 14
#  	 Train Loss:1.05 	 Train Acc:0.57
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.00
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.01 	 Val (with Target) Acc:0.61
# Epoch: 15
#  	 Train Loss:1.05 	 Train Acc:0.56
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.19
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:9.85 	 Val (with Target) Acc:0.57
# Epoch: 16
#  	 Train Loss:0.99 	 Train Acc:0.58
# 	 Train (Adv) Loss:0.95 	 Train (Replay) Loss:1.23
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:10.26 	 Val (with Target) Acc:0.62
# Epoch: 17
#  	 Train Loss:1.02 	 Train Acc:0.57
# 	 Train (Adv) Loss:0.99 	 Train (Replay) Loss:1.07
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.56 	 Val (with Target) Acc:0.62
# Epoch: 18
#  	 Train Loss:1.03 	 Train Acc:0.57
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:0.60
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:11.31 	 Val (with Target) Acc:0.57
# Epoch: 19
#  	 Train Loss:1.06 	 Train Acc:0.58
# 	 Train (Adv) Loss:1.04 	 Train (Replay) Loss:0.72
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:10.40 	 Val (with Target) Acc:0.57
# Epoch: 20
#  	 Train Loss:1.03 	 Train Acc:0.58
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:0.78
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:11.21 	 Val (with Target) Acc:0.57
# Epoch: 21
#  	 Train Loss:1.07 	 Train Acc:0.58
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:0.78
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.80 	 Val (with Target) Acc:0.62
# Epoch: 22
#  	 Train Loss:1.03 	 Train Acc:0.54
# 	 Train (Adv) Loss:0.98 	 Train (Replay) Loss:1.70
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:13.10 	 Val (with Target) Acc:0.42
# Epoch: 23
#  	 Train Loss:0.99 	 Train Acc:0.52
# 	 Train (Adv) Loss:0.91 	 Train (Replay) Loss:2.48
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:15.26 	 Val (with Target) Acc:0.55
# Epoch: 24
#  	 Train Loss:1.07 	 Train Acc:0.54
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:2.24
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:13.72 	 Val (with Target) Acc:0.53
# Epoch: 25
#  	 Train Loss:1.10 	 Train Acc:0.52
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:1.68
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:13.68 	 Val (with Target) Acc:0.52
# Epoch: 26
#  	 Train Loss:1.12 	 Train Acc:0.54
# 	 Train (Adv) Loss:1.09 	 Train (Replay) Loss:0.82
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:12.27 	 Val (with Target) Acc:0.53
# Epoch: 27
#  	 Train Loss:1.08 	 Train Acc:0.54
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:0.79
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:12.46 	 Val (with Target) Acc:0.49
# Epoch: 28
#  	 Train Loss:1.03 	 Train Acc:0.57
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:0.77
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:11.08 	 Val (with Target) Acc:0.62
# Epoch: 29
#  	 Train Loss:1.04 	 Train Acc:0.55
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:0.70
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:11.22 	 Val (with Target) Acc:0.57
# Epoch: 30
#  	 Train Loss:1.03 	 Train Acc:0.58
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:0.64
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:11.81 	 Val (with Target) Acc:0.54
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:1.05 	 Test (with Source) Acc:0.73
# Target Domain F:
# 	 Test (with Target) Loss:8.41 	 Test (with Target) Acc:0.51
# Target Domain G:
# 	 Test (with Target) Loss:9.90 	 Test (with Target) Acc:0.55
# Target Domain H:
# 	 Test (with Target) Loss:11.39 	 Test (with Target) Acc:0.54
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 9600
#
# Phase 4 (Domain H to Domain A)
# Epoch: 1
#  	 Train Loss:1.07 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:2.08
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:10.65 	 Val (with Target) Acc:0.42
# Epoch: 2
#  	 Train Loss:1.30 	 Train Acc:0.36
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:2.19
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:14.82 	 Val (with Target) Acc:0.43
# Epoch: 3
#  	 Train Loss:1.10 	 Train Acc:0.39
# 	 Train (Adv) Loss:1.07 	 Train (Replay) Loss:1.27
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:8.57 	 Val (with Target) Acc:0.30
# Epoch: 4
#  	 Train Loss:1.05 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:0.89
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:12.52 	 Val (with Target) Acc:0.29
# Epoch: 5
#  	 Train Loss:1.05 	 Train Acc:0.36
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.13
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:12.75 	 Val (with Target) Acc:0.35
# Epoch: 6
#  	 Train Loss:1.17 	 Train Acc:0.34
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:1.71
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:16.91 	 Val (with Target) Acc:0.33
# Epoch: 7
#  	 Train Loss:1.13 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.08 	 Train (Replay) Loss:1.50
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:11.48 	 Val (with Target) Acc:0.36
# Epoch: 8
#  	 Train Loss:1.17 	 Train Acc:0.35
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:1.69
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:14.19 	 Val (with Target) Acc:0.36
# Epoch: 9
#  	 Train Loss:1.13 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.10 	 Train (Replay) Loss:0.96
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:13.03 	 Val (with Target) Acc:0.31
# Epoch: 10
#  	 Train Loss:1.22 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.16 	 Train (Replay) Loss:1.79
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:19.86 	 Val (with Target) Acc:0.25
# Epoch: 11
#  	 Train Loss:1.14 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:1.08
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:15.13 	 Val (with Target) Acc:0.35
# Epoch: 12
#  	 Train Loss:1.13 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.09 	 Train (Replay) Loss:1.15
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:13.72 	 Val (with Target) Acc:0.34
# Epoch: 13
#  	 Train Loss:1.31 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:3.38
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:19.11 	 Val (with Target) Acc:0.25
# Epoch: 14
#  	 Train Loss:1.27 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.14 	 Train (Replay) Loss:4.48
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:17.20 	 Val (with Target) Acc:0.34
# Epoch: 15
#  	 Train Loss:1.04 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:1.26
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:11.51 	 Val (with Target) Acc:0.31
# Epoch: 16
#  	 Train Loss:1.12 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.09 	 Train (Replay) Loss:1.05
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:17.26 	 Val (with Target) Acc:0.25
# Epoch: 17
#  	 Train Loss:1.13 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.10 	 Train (Replay) Loss:1.01
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:13.81 	 Val (with Target) Acc:0.32
# Epoch: 18
#  	 Train Loss:1.16 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:0.94
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:17.77 	 Val (with Target) Acc:0.29
# Epoch: 19
#  	 Train Loss:1.19 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.14 	 Train (Replay) Loss:1.47
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:14.04 	 Val (with Target) Acc:0.32
# Epoch: 20
#  	 Train Loss:1.17 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.14 	 Train (Replay) Loss:1.05
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:14.19 	 Val (with Target) Acc:0.26
# Epoch: 21
#  	 Train Loss:1.23 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.18 	 Train (Replay) Loss:1.67
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:14.37 	 Val (with Target) Acc:0.28
# Epoch: 22
#  	 Train Loss:1.15 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:0.99
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:13.91 	 Val (with Target) Acc:0.25
# Epoch: 23
#  	 Train Loss:1.19 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.15 	 Train (Replay) Loss:1.41
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:25.56 	 Val (with Target) Acc:0.25
# Epoch: 24
#  	 Train Loss:1.32 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.19 	 Train (Replay) Loss:4.29
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:18.09 	 Val (with Target) Acc:0.36
# Epoch: 25
#  	 Train Loss:1.15 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.06 	 Train (Replay) Loss:3.01
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:11.32 	 Val (with Target) Acc:0.32
# Epoch: 26
#  	 Train Loss:0.98 	 Train Acc:0.32
# 	 Train (Adv) Loss:0.95 	 Train (Replay) Loss:0.97
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:11.51 	 Val (with Target) Acc:0.32
# Epoch: 27
#  	 Train Loss:1.06 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.03 	 Train (Replay) Loss:1.00
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:12.38 	 Val (with Target) Acc:0.26
# Epoch: 28
#  	 Train Loss:1.15 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:1.18
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:14.64 	 Val (with Target) Acc:0.30
# Epoch: 29
#  	 Train Loss:1.20 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.17 	 Train (Replay) Loss:1.26
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:18.40 	 Val (with Target) Acc:0.28
# Epoch: 30
#  	 Train Loss:1.12 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.09 	 Train (Replay) Loss:1.15
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:13.98 	 Val (with Target) Acc:0.27
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:1.76 	 Test (with Source) Acc:0.69
# Target Domain F:
# 	 Test (with Target) Loss:7.90 	 Test (with Target) Acc:0.66
# Target Domain G:
# 	 Test (with Target) Loss:8.52 	 Test (with Target) Acc:0.68
# Target Domain H:
# 	 Test (with Target) Loss:11.28 	 Test (with Target) Acc:0.62
# Target Domain A:
# 	 Test (with Target) Loss:15.69 	 Test (with Target) Acc:0.27
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 12000
#
# Phase 5 (Domain A to Domain B)
# Epoch: 1
#  	 Train Loss:1.27 	 Train Acc:0.35
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.02
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:18.08 	 Val (with Target) Acc:0.27
# Epoch: 2
#  	 Train Loss:1.33 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:2.78
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:11.95 	 Val (with Target) Acc:0.25
# Epoch: 3
#  	 Train Loss:1.19 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.14 	 Train (Replay) Loss:1.68
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:9.21 	 Val (with Target) Acc:0.33
# Epoch: 4
#  	 Train Loss:1.25 	 Train Acc:0.34
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.41
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.76
# 	 Val (with Target) Loss:18.01 	 Val (with Target) Acc:0.29
# Epoch: 5
#  	 Train Loss:1.22 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.17 	 Train (Replay) Loss:1.44
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:11.53 	 Val (with Target) Acc:0.42
# Epoch: 6
#  	 Train Loss:1.28 	 Train Acc:0.36
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.11
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:9.43 	 Val (with Target) Acc:0.35
# Epoch: 7
#  	 Train Loss:1.32 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:2.34
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:9.20 	 Val (with Target) Acc:0.32
# Epoch: 8
#  	 Train Loss:1.16 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:1.12
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:11.00 	 Val (with Target) Acc:0.26
# Epoch: 9
#  	 Train Loss:1.38 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.30 	 Train (Replay) Loss:2.70
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:10.89 	 Val (with Target) Acc:0.33
# Epoch: 10
#  	 Train Loss:1.29 	 Train Acc:0.38
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.19
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:11.38 	 Val (with Target) Acc:0.41
# Epoch: 11
#  	 Train Loss:1.43 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.35 	 Train (Replay) Loss:2.67
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:21.15 	 Val (with Target) Acc:0.33
# Epoch: 12
#  	 Train Loss:1.18 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.14 	 Train (Replay) Loss:1.55
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:9.90 	 Val (with Target) Acc:0.34
# Epoch: 13
#  	 Train Loss:1.37 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:3.62
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:14.79 	 Val (with Target) Acc:0.29
# Epoch: 14
#  	 Train Loss:1.23 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.20 	 Train (Replay) Loss:1.20
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:13.22 	 Val (with Target) Acc:0.24
# Epoch: 15
#  	 Train Loss:1.30 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.60
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:13.64 	 Val (with Target) Acc:0.36
# Epoch: 16
#  	 Train Loss:1.28 	 Train Acc:0.36
# 	 Train (Adv) Loss:1.22 	 Train (Replay) Loss:1.90
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:12.95 	 Val (with Target) Acc:0.37
# Epoch: 17
#  	 Train Loss:1.35 	 Train Acc:0.35
# 	 Train (Adv) Loss:1.30 	 Train (Replay) Loss:1.67
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:15.03 	 Val (with Target) Acc:0.32
# Epoch: 18
#  	 Train Loss:1.37 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.31 	 Train (Replay) Loss:1.81
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:15.76 	 Val (with Target) Acc:0.35
# Epoch: 19
#  	 Train Loss:1.55 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.44 	 Train (Replay) Loss:3.60
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:25.53 	 Val (with Target) Acc:0.25
# Epoch: 20
#  	 Train Loss:1.50 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.35 	 Train (Replay) Loss:5.10
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:11.33 	 Val (with Target) Acc:0.28
# Epoch: 21
#  	 Train Loss:1.18 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.15 	 Train (Replay) Loss:1.02
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:10.28 	 Val (with Target) Acc:0.30
# Epoch: 22
#  	 Train Loss:1.32 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:2.45
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:20.87 	 Val (with Target) Acc:0.19
# Epoch: 23
#  	 Train Loss:1.46 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:4.62
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:21.30 	 Val (with Target) Acc:0.27
# Epoch: 24
#  	 Train Loss:1.35 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:3.76
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:12.26 	 Val (with Target) Acc:0.21
# Epoch: 25
#  	 Train Loss:1.26 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.18 	 Train (Replay) Loss:2.61
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:17.88 	 Val (with Target) Acc:0.26
# Epoch: 26
#  	 Train Loss:1.31 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:2.50
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:14.49 	 Val (with Target) Acc:0.19
# Epoch: 27
#  	 Train Loss:1.21 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.16 	 Train (Replay) Loss:1.69
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:14.74 	 Val (with Target) Acc:0.25
# Epoch: 28
#  	 Train Loss:1.44 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:3.50
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:15.43 	 Val (with Target) Acc:0.27
# Epoch: 29
#  	 Train Loss:1.42 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.31 	 Train (Replay) Loss:3.49
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:16.91 	 Val (with Target) Acc:0.26
# Epoch: 30
#  	 Train Loss:1.34 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:2.68
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:20.04 	 Val (with Target) Acc:0.25
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:2.07 	 Test (with Source) Acc:0.62
# Target Domain F:
# 	 Test (with Target) Loss:8.93 	 Test (with Target) Acc:0.48
# Target Domain G:
# 	 Test (with Target) Loss:8.92 	 Test (with Target) Acc:0.46
# Target Domain H:
# 	 Test (with Target) Loss:9.88 	 Test (with Target) Acc:0.46
# Target Domain A:
# 	 Test (with Target) Loss:21.75 	 Test (with Target) Acc:0.18
# Target Domain B:
# 	 Test (with Target) Loss:19.95 	 Test (with Target) Acc:0.26
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 14400
#
# Phase 6 (Domain B to Domain C)
# Epoch: 1
#  	 Train Loss:1.27 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.94
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:16.69 	 Val (with Target) Acc:0.30
# Epoch: 2
#  	 Train Loss:1.31 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.88
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:18.31 	 Val (with Target) Acc:0.28
# Epoch: 3
#  	 Train Loss:1.30 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.90
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:15.36 	 Val (with Target) Acc:0.29
# Epoch: 4
#  	 Train Loss:1.32 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.97
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:15.31 	 Val (with Target) Acc:0.28
# Epoch: 5
#  	 Train Loss:1.33 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.74
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:16.88 	 Val (with Target) Acc:0.27
# Epoch: 6
#  	 Train Loss:1.33 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.94
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:17.64 	 Val (with Target) Acc:0.28
# Epoch: 7
#  	 Train Loss:1.35 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:2.03
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:14.51 	 Val (with Target) Acc:0.27
# Epoch: 8
#  	 Train Loss:1.31 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.68
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:16.73 	 Val (with Target) Acc:0.26
# Epoch: 9
#  	 Train Loss:1.33 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.82
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.82 	 Val (with Target) Acc:0.29
# Epoch: 10
#  	 Train Loss:1.30 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.70
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.21 	 Val (with Target) Acc:0.28
# Epoch: 11
#  	 Train Loss:1.32 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.74
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.33 	 Val (with Target) Acc:0.27
# Epoch: 12
#  	 Train Loss:1.31 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.92
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:17.93 	 Val (with Target) Acc:0.27
# Epoch: 13
#  	 Train Loss:1.35 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:2.01
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:15.59 	 Val (with Target) Acc:0.27
# Epoch: 14
#  	 Train Loss:1.34 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.74
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:14.89 	 Val (with Target) Acc:0.29
# Epoch: 15
#  	 Train Loss:1.33 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:2.00
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:16.35 	 Val (with Target) Acc:0.27
# Epoch: 16
#  	 Train Loss:1.31 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.83
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:14.43 	 Val (with Target) Acc:0.25
# Epoch: 17
#  	 Train Loss:1.33 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.74
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:17.41 	 Val (with Target) Acc:0.29
# Epoch: 18
#  	 Train Loss:1.33 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.72
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:16.98 	 Val (with Target) Acc:0.26
# Epoch: 19
#  	 Train Loss:1.30 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.76
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:13.87 	 Val (with Target) Acc:0.24
# Epoch: 20
#  	 Train Loss:1.32 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.64
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:14.04 	 Val (with Target) Acc:0.27
# Epoch: 21
#  	 Train Loss:1.29 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.18 	 Train (Replay) Loss:3.51
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:14.45 	 Val (with Target) Acc:0.28
# Epoch: 22
#  	 Train Loss:1.38 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.34 	 Train (Replay) Loss:1.55
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:17.62 	 Val (with Target) Acc:0.26
# Epoch: 23
#  	 Train Loss:1.39 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.34 	 Train (Replay) Loss:1.80
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:18.63 	 Val (with Target) Acc:0.26
# Epoch: 24
#  	 Train Loss:1.35 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.30 	 Train (Replay) Loss:1.83
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:15.66 	 Val (with Target) Acc:0.25
# Epoch: 25
#  	 Train Loss:1.30 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.56
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:18.59 	 Val (with Target) Acc:0.27
# Epoch: 26
#  	 Train Loss:1.36 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.32 	 Train (Replay) Loss:1.51
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:12.44 	 Val (with Target) Acc:0.27
# Epoch: 27
#  	 Train Loss:1.34 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:1.63
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:17.34 	 Val (with Target) Acc:0.25
# Epoch: 28
#  	 Train Loss:1.31 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.52
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:16.86 	 Val (with Target) Acc:0.26
# Epoch: 29
#  	 Train Loss:1.34 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:1.60
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:14.53 	 Val (with Target) Acc:0.28
# Epoch: 30
#  	 Train Loss:1.33 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:1.41
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:17.89 	 Val (with Target) Acc:0.27
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:1.06 	 Test (with Source) Acc:0.66
# Target Domain F:
# 	 Test (with Target) Loss:7.08 	 Test (with Target) Acc:0.55
# Target Domain G:
# 	 Test (with Target) Loss:7.58 	 Test (with Target) Acc:0.51
# Target Domain H:
# 	 Test (with Target) Loss:8.47 	 Test (with Target) Acc:0.44
# Target Domain A:
# 	 Test (with Target) Loss:19.96 	 Test (with Target) Acc:0.20
# Target Domain B:
# 	 Test (with Target) Loss:17.92 	 Test (with Target) Acc:0.26
# Target Domain C:
# 	 Test (with Target) Loss:18.24 	 Test (with Target) Acc:0.26
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 16800
#
# Phase 7 (Domain C to Domain D)
# Epoch: 1
#  	 Train Loss:1.37 	 Train Acc:0.35
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:1.28
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:9.71 	 Val (with Target) Acc:0.42
# Epoch: 2
#  	 Train Loss:1.33 	 Train Acc:0.37
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:1.32
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:13.31 	 Val (with Target) Acc:0.36
# Epoch: 3
#  	 Train Loss:1.36 	 Train Acc:0.34
# 	 Train (Adv) Loss:1.31 	 Train (Replay) Loss:1.44
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:12.38 	 Val (with Target) Acc:0.35
# Epoch: 4
#  	 Train Loss:1.38 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.32 	 Train (Replay) Loss:1.70
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:18.98 	 Val (with Target) Acc:0.23
# Epoch: 5
#  	 Train Loss:1.41 	 Train Acc:0.28
# 	 Train (Adv) Loss:1.36 	 Train (Replay) Loss:1.96
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:14.82 	 Val (with Target) Acc:0.35
# Epoch: 6
#  	 Train Loss:1.33 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:3.49
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:15.45 	 Val (with Target) Acc:0.35
# Epoch: 7
#  	 Train Loss:1.42 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.37 	 Train (Replay) Loss:1.93
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:12.81 	 Val (with Target) Acc:0.34
# Epoch: 8
#  	 Train Loss:1.35 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:2.14
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:7.37 	 Val (with Target) Acc:0.34
# Epoch: 9
#  	 Train Loss:1.40 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:2.39
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:17.02 	 Val (with Target) Acc:0.35
# Epoch: 10
#  	 Train Loss:1.39 	 Train Acc:0.34
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:2.02
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:16.76 	 Val (with Target) Acc:0.36
# Epoch: 11
#  	 Train Loss:1.34 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.80
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:17.44 	 Val (with Target) Acc:0.35
# Epoch: 12
#  	 Train Loss:1.35 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:2.10
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:12.86 	 Val (with Target) Acc:0.32
# Epoch: 13
#  	 Train Loss:1.33 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.81
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:13.32 	 Val (with Target) Acc:0.35
# Epoch: 14
#  	 Train Loss:1.27 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.19 	 Train (Replay) Loss:2.58
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.76
# 	 Val (with Target) Loss:10.57 	 Val (with Target) Acc:0.33
# Epoch: 15
#  	 Train Loss:1.45 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.38 	 Train (Replay) Loss:2.27
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:17.15 	 Val (with Target) Acc:0.34
# Epoch: 16
#  	 Train Loss:1.39 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:1.82
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:16.02 	 Val (with Target) Acc:0.32
# Epoch: 17
#  	 Train Loss:1.37 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.31 	 Train (Replay) Loss:2.00
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.23 	 Val (with Target) Acc:0.35
# Epoch: 18
#  	 Train Loss:1.40 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:2.28
# 	 Discriminator Loss:0.48 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:21.97 	 Val (with Target) Acc:0.28
# Epoch: 19
#  	 Train Loss:1.39 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:1.96
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.34 	 Val (with Target) Acc:0.33
# Epoch: 20
#  	 Train Loss:1.37 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.32 	 Train (Replay) Loss:1.84
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:16.25 	 Val (with Target) Acc:0.35
# Epoch: 21
#  	 Train Loss:1.37 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.30 	 Train (Replay) Loss:2.10
# 	 Discriminator Loss:0.49 	 Discriminator Acc:0.76
# 	 Val (with Target) Loss:17.63 	 Val (with Target) Acc:0.35
# Epoch: 22
#  	 Train Loss:1.40 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.35 	 Train (Replay) Loss:1.83
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:16.70 	 Val (with Target) Acc:0.34
# Epoch: 23
#  	 Train Loss:1.39 	 Train Acc:0.30
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:2.11
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:15.99 	 Val (with Target) Acc:0.31
# Epoch: 24
#  	 Train Loss:1.39 	 Train Acc:0.29
# 	 Train (Adv) Loss:1.32 	 Train (Replay) Loss:2.26
# 	 Discriminator Loss:0.50 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:17.59 	 Val (with Target) Acc:0.34
# Epoch: 25
#  	 Train Loss:1.41 	 Train Acc:0.33
# 	 Train (Adv) Loss:1.35 	 Train (Replay) Loss:2.10
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:19.69 	 Val (with Target) Acc:0.34
# Epoch: 26
#  	 Train Loss:1.36 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.31 	 Train (Replay) Loss:1.85
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:20.37 	 Val (with Target) Acc:0.33
# Epoch: 27
#  	 Train Loss:1.35 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.29 	 Train (Replay) Loss:1.82
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:17.92 	 Val (with Target) Acc:0.32
# Epoch: 28
#  	 Train Loss:1.29 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.19 	 Train (Replay) Loss:3.46
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:11.25 	 Val (with Target) Acc:0.32
# Epoch: 29
#  	 Train Loss:1.50 	 Train Acc:0.31
# 	 Train (Adv) Loss:1.44 	 Train (Replay) Loss:2.24
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:20.18 	 Val (with Target) Acc:0.35
# Epoch: 30
#  	 Train Loss:1.37 	 Train Acc:0.32
# 	 Train (Adv) Loss:1.32 	 Train (Replay) Loss:1.77
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:15.21 	 Val (with Target) Acc:0.35
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:1.46 	 Test (with Source) Acc:0.57
# Target Domain F:
# 	 Test (with Target) Loss:6.29 	 Test (with Target) Acc:0.53
# Target Domain G:
# 	 Test (with Target) Loss:7.15 	 Test (with Target) Acc:0.52
# Target Domain H:
# 	 Test (with Target) Loss:8.36 	 Test (with Target) Acc:0.41
# Target Domain A:
# 	 Test (with Target) Loss:18.16 	 Test (with Target) Acc:0.13
# Target Domain B:
# 	 Test (with Target) Loss:16.49 	 Test (with Target) Acc:0.23
# Target Domain C:
# 	 Test (with Target) Loss:16.20 	 Test (with Target) Acc:0.25
# Target Domain D:
# 	 Test (with Target) Loss:15.45 	 Test (with Target) Acc:0.34
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 19200

# %%
generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_src, "cuda")
src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_tgt[phase], "cuda")
    tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[phase])
    print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# 	 Test (with Source) Loss:1.46 	 Test (with Source) Acc:0.57
#
# Phase 1 (Domain E to Domain F)
# 	 Test (with Target) Loss:6.29 	 Test (with Target) Acc:0.53
#
# Phase 2 (Domain F to Domain G)
# 	 Test (with Target) Loss:7.15 	 Test (with Target) Acc:0.52
#
# Phase 3 (Domain G to Domain H)
# 	 Test (with Target) Loss:8.36 	 Test (with Target) Acc:0.41
#
# Phase 4 (Domain H to Domain A)
# 	 Test (with Target) Loss:18.16 	 Test (with Target) Acc:0.13
#
# Phase 5 (Domain A to Domain B)
# 	 Test (with Target) Loss:16.49 	 Test (with Target) Acc:0.23
#
# Phase 6 (Domain B to Domain C)
# 	 Test (with Target) Loss:16.20 	 Test (with Target) Acc:0.25
#
# Phase 7 (Domain C to Domain D)
# 	 Test (with Target) Loss:15.45 	 Test (with Target) Acc:0.34
