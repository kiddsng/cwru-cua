# %% [markdown]
# ### Adversarial Discriminative Domain Adaptation

# %%
# import modules and libraries
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable

# functions to create datasets and models
from data.data import *
from models.models import *

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available')
else:
    print('CUDA is available')
    device = torch.device('cuda')
# Out:
# CUDA is available

# %% [markdown]
# ### Parameters

# %%
"""Parameters for this experiment"""
# params for loading the data
path = 'data/CWRU/bearing/'
source_domain = 'E'
target_domains = ['F', 'G', 'H', 'A', 'B', 'C', 'D']

# params for configuring the model
input_dim = 1
hidden_dim = 256
output_dim = 10
drop_prob = 0.5

# params for training the model
epochs_pre = 30 # pre-training
epochs = 30

# optimizing the model
lr = 1e-4
d_lr = 1e-4
batch_size = 20
beta1 = 0.5
beta2 = 0.9

# %% [markdown]
# ### Data Loading

# %%
# source domain data for training, validating and testing
train_dataloader_src, val_dataloader_src, test_dataloader_src = generate_dataloaders(path, source_domain, batch_size)

# target domain data for validating and testing
train_dataloader_tgt, val_dataloader_tgt, test_dataloader_tgt = [], [], []
for target_domain in target_domains:
    train_dataloader_temp, val_dataloader_temp, test_dataloader_temp = generate_dataloaders(path, target_domain, batch_size)
    
    train_dataloader_tgt.append(train_dataloader_temp)
    val_dataloader_tgt.append(val_dataloader_temp)
    test_dataloader_tgt.append(test_dataloader_temp)

# %% [markdown]
# ### Model

# %%
encoder_src = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim # hidden layers 64
)

classifier = Classifier_AMDA(
    hidden_dim=hidden_dim, # hidden layers 64
    output_dim=output_dim, # 3 classes (healthy, inner- and outer-bearing damages)
    dropout=drop_prob # dropout prob 0.5
)

encoder_tgt = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim, # hidden layers 64
)

discriminator = Discriminator(
    hidden_dim=hidden_dim
)

if train_on_gpu:
    encoder_src = encoder_src.to(device)
    classifier = classifier.to(device)
    encoder_tgt = encoder_tgt.to(device)
    discriminator = discriminator.to(device)

# %% [markdown]
# #### Functions for training and testing the model

# %%
# functions for training source encoder and shared classifier
def train_src(encoder, classifier):
    """Train the source encoder and shared classifier on source domain"""
    encoder.train()
    classifier.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        list(encoder.parameters()) + list(classifier.parameters()),
        lr=lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs_pre):
        accuracies = []
        losses = []

        for batch_idx, (x_src, y_src) in enumerate(train_dataloader_src):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            optimizer.zero_grad()

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            loss_src.backward()

            optimizer.step()

            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_src(encoder, classifier, phase = 'Val')
        print(f'\t Val Loss:{val_loss:0.2f} \t\t Val Acc:{val_acc:0.2f}')

    return encoder, classifier

# testing model on source domain
def evaluate_src(encoder, classifier, phase='Val'): # phase can be validate or test
    """Evaluate the trained network on source domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    dataloader = val_dataloader_src if phase == 'Val' else test_dataloader_src
    
    with torch.no_grad():
        for batch_idx, (x_src, y_src) in enumerate(dataloader):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            
            # append loss for each batch
            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# Continuous Unsupervised Adaptation (CUA)
# functions for training target encoder
def train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase):
    """Train the target encoder on target domains with source encoder and test the network"""
    encoder_tgt.train()
    discriminator.train()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        encoder_tgt.parameters(),
        lr=lr,
        betas=(beta1, beta2)
    )
    d_optimizer = Adam(
        discriminator.parameters(),
        lr=d_lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs):
        losses = []
        losses_d = []
        accuracies = []
        accuracies_d = []

        for batch_idx, ((x_src, y_src), (x_tgt, y_tgt)) in enumerate(zip(train_dataloader_src, train_dataloader_tgt[phase])):
            if(train_on_gpu):
                x_src, y_src = x_src.to(device), y_src.to(device)
                x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)

            optimizer.zero_grad()
            d_optimizer.zero_grad()

            # part 1: sequential unsupervised adaptation
            # learn e_src and _tgt: source and target mapping represenations
            e_src = encoder_src(x_src)
            e_tgt = encoder_tgt(x_tgt)
            e_concat = torch.concat((e_src.detach(), e_tgt.detach()), 0)
            # minimize distance between source and target empirical mapping distribution using adversarial discriminator
            d_concat = discriminator(e_concat)

            label_src = Variable(torch.ones(e_src.size(0)).long()).to(device)
            label_tgt = Variable(torch.zeros(e_tgt.size(0)).long()).to(device)
            label_concat = torch.cat((label_src, label_tgt), 0)

            loss_d = criterion(d_concat, label_concat)
            loss_d.backward()
            d_optimizer.step()

            e_tgt = encoder_tgt(x_tgt)
            pred_tgt = classifier(e_tgt)
            d_tgt = discriminator(e_tgt)
            label_tgt = Variable(torch.ones(e_tgt.size(0)).long()).to(device)
            loss = criterion(d_tgt, label_tgt)

            loss.backward()
            optimizer.step()
            
            # training (with replay) losses and accuracies
            losses.append(loss.detach().item()) # detach the loss from compute graph
            losses_d.append(loss_d.detach().item())
            accuracies.append(y_tgt.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            accuracies_d.append(torch.squeeze(d_concat.max(1)[1]).eq(label_concat.detach()).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train (with Adv) Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')
        print(f'\t Discriminator Loss:{torch.tensor(losses_d).mean():0.2f} \t Discriminator Acc:{torch.tensor(accuracies_d).mean():0.2f} ')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_tgt(encoder_tgt, classifier, val_dataloader_tgt[phase])
        print(f'\t Val (with Target) Loss:{val_loss:0.2f} \t Val (with Target) Acc:{val_acc:0.2f}')

    return encoder_tgt
    
# testing model on target domains

def evaluate_tgt(encoder, classifier, dataloader):
    """Evaluate the network on current target domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    
    with torch.no_grad():
        for batch_idx, (x, y) in enumerate(dataloader): # target dataloader
            if(train_on_gpu):
                x, y = x.to(device), y.to(device)

            pred_tgt = classifier(encoder(x))
            loss_tgt = criterion(pred_tgt, y)
            
            # append loss for each batch
            losses.append(loss_tgt.detach().item()) # detach the loss from compute graph 
            accuracies.append(y.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %% [markdown]
# ### Pre-training

# %%
# pre-training
# encoder_src, classifier = train_src(encoder_src, classifier)
# torch.save(encoder_src.state_dict(), './dump/source_encoder_cwru_cua_adda5.pt')
# torch.save(classifier.state_dict(), './dump/classifier_cwru_cua_adda5.pt')
encoder_src.load_state_dict(torch.load('./dump/source_encoder_cwru_cua_adda5.pt'))
classifier.load_state_dict(torch.load('./dump/classifier_cwru_cua_adda5.pt'))
src_test_loss, src_test_acc = evaluate_src(encoder_src, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}')
# Out:
# 	 Test (with Source) Loss:0.15 	 Test (with Source) Acc:0.94

# %%
encoder_tgt.load_state_dict(encoder_src.state_dict())

# adaptation
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    encoder_tgt = train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase)
    
    print('\nTesting Accuracy on Previously Seen and Current Domains:')
    print(f'Source Domain {source_domain}:')
    src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
    print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
    for p in range(phase + 1):
        print(f'Target Domain {target_domains[p]}:')
        tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[p])
        print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# Phase 1 (Domain E to Domain F)
# Epoch: 1
#  	 Train (with Adv) Loss:0.69 	 Train Acc:0.47
# 	 Discriminator Loss:0.86 	 Discriminator Acc:0.46
# 	 Val (with Target) Loss:9.80 	 Val (with Target) Acc:0.48
# Epoch: 2
#  	 Train (with Adv) Loss:0.74 	 Train Acc:0.56
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:6.89 	 Val (with Target) Acc:0.62
# Epoch: 3
#  	 Train (with Adv) Loss:0.78 	 Train Acc:0.57
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:8.40 	 Val (with Target) Acc:0.63
# Epoch: 4
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.58
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:7.81 	 Val (with Target) Acc:0.45
# Epoch: 5
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.56
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:9.43 	 Val (with Target) Acc:0.62
# Epoch: 6
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.53
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:8.81 	 Val (with Target) Acc:0.63
# Epoch: 7
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.58
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:8.17 	 Val (with Target) Acc:0.55
# Epoch: 8
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.54
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:7.41 	 Val (with Target) Acc:0.51
# Epoch: 9
#  	 Train (with Adv) Loss:0.79 	 Train Acc:0.56
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:7.90 	 Val (with Target) Acc:0.52
# Epoch: 10
#  	 Train (with Adv) Loss:0.82 	 Train Acc:0.53
# 	 Discriminator Loss:0.69 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:10.20 	 Val (with Target) Acc:0.58
# Epoch: 11
#  	 Train (with Adv) Loss:0.80 	 Train Acc:0.56
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:7.75 	 Val (with Target) Acc:0.62
# Epoch: 12
#  	 Train (with Adv) Loss:0.86 	 Train Acc:0.63
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:9.17 	 Val (with Target) Acc:0.62
# Epoch: 13
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.60
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:7.04 	 Val (with Target) Acc:0.75
# Epoch: 14
#  	 Train (with Adv) Loss:0.81 	 Train Acc:0.51
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:8.33 	 Val (with Target) Acc:0.57
# Epoch: 15
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.58
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:8.52 	 Val (with Target) Acc:0.62
# Epoch: 16
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.64
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:6.32 	 Val (with Target) Acc:0.68
# Epoch: 17
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.57
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:11.68 	 Val (with Target) Acc:0.32
# Epoch: 18
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.51
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:8.94 	 Val (with Target) Acc:0.48
# Epoch: 19
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.54
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:11.25 	 Val (with Target) Acc:0.39
# Epoch: 20
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.57
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:6.84 	 Val (with Target) Acc:0.58
# Epoch: 21
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.53
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:8.99 	 Val (with Target) Acc:0.53
# Epoch: 22
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.50
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:15.56 	 Val (with Target) Acc:0.23
# Epoch: 23
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.51
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:7.15 	 Val (with Target) Acc:0.65
# Epoch: 24
#  	 Train (with Adv) Loss:0.84 	 Train Acc:0.53
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:11.04 	 Val (with Target) Acc:0.41
# Epoch: 25
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.45
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:10.79 	 Val (with Target) Acc:0.43
# Epoch: 26
#  	 Train (with Adv) Loss:0.83 	 Train Acc:0.53
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:10.71 	 Val (with Target) Acc:0.41
# Epoch: 27
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.53
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:10.76 	 Val (with Target) Acc:0.43
# Epoch: 28
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.57
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:11.21 	 Val (with Target) Acc:0.41
# Epoch: 29
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.53
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:6.94 	 Val (with Target) Acc:0.64
# Epoch: 30
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.53
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:8.96 	 Val (with Target) Acc:0.56
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:1.18 	 Test (with Source) Acc:0.69
# Target Domain F:
# 	 Test (with Target) Loss:8.05 	 Test (with Target) Acc:0.55
#
# Phase 2 (Domain F to Domain G)
# Epoch: 1
#  	 Train (with Adv) Loss:0.85 	 Train Acc:0.52
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:9.05 	 Val (with Target) Acc:0.53
# Epoch: 2
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.46
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:9.65 	 Val (with Target) Acc:0.55
# Epoch: 3
#  	 Train (with Adv) Loss:0.87 	 Train Acc:0.48
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:12.10 	 Val (with Target) Acc:0.46
# Epoch: 4
#  	 Train (with Adv) Loss:0.89 	 Train Acc:0.44
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:9.35 	 Val (with Target) Acc:0.56
# Epoch: 5
#  	 Train (with Adv) Loss:0.90 	 Train Acc:0.45
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:10.21 	 Val (with Target) Acc:0.51
# Epoch: 6
#  	 Train (with Adv) Loss:0.91 	 Train Acc:0.44
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:10.01 	 Val (with Target) Acc:0.52
# Epoch: 7
#  	 Train (with Adv) Loss:0.91 	 Train Acc:0.47
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:12.47 	 Val (with Target) Acc:0.44
# Epoch: 8
#  	 Train (with Adv) Loss:0.93 	 Train Acc:0.43
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:9.27 	 Val (with Target) Acc:0.56
# Epoch: 9
#  	 Train (with Adv) Loss:0.94 	 Train Acc:0.45
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:12.58 	 Val (with Target) Acc:0.40
# Epoch: 10
#  	 Train (with Adv) Loss:0.92 	 Train Acc:0.47
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:12.18 	 Val (with Target) Acc:0.42
# Epoch: 11
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.43
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:11.37 	 Val (with Target) Acc:0.46
# Epoch: 12
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.41
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:10.51 	 Val (with Target) Acc:0.52
# Epoch: 13
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.40
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:11.86 	 Val (with Target) Acc:0.43
# Epoch: 14
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.39
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:13.96 	 Val (with Target) Acc:0.38
# Epoch: 15
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.39
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:11.07 	 Val (with Target) Acc:0.46
# Epoch: 16
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.42
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:11.12 	 Val (with Target) Acc:0.47
# Epoch: 17
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.41
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:12.91 	 Val (with Target) Acc:0.42
# Epoch: 18
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.42
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:10.53 	 Val (with Target) Acc:0.43
# Epoch: 19
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.40
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:14.14 	 Val (with Target) Acc:0.40
# Epoch: 20
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.42
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:12.30 	 Val (with Target) Acc:0.44
# Epoch: 21
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.42
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:15.65 	 Val (with Target) Acc:0.35
# Epoch: 22
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.41
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:11.67 	 Val (with Target) Acc:0.46
# Epoch: 23
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.40
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:14.16 	 Val (with Target) Acc:0.39
# Epoch: 24
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.43
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:12.75 	 Val (with Target) Acc:0.44
# Epoch: 25
#  	 Train (with Adv) Loss:0.95 	 Train Acc:0.43
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:11.65 	 Val (with Target) Acc:0.45
# Epoch: 26
#  	 Train (with Adv) Loss:0.94 	 Train Acc:0.43
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:18.82 	 Val (with Target) Acc:0.28
# Epoch: 27
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.42
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:13.68 	 Val (with Target) Acc:0.43
# Epoch: 28
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.42
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:15.30 	 Val (with Target) Acc:0.38
# Epoch: 29
#  	 Train (with Adv) Loss:0.96 	 Train Acc:0.44
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:14.36 	 Val (with Target) Acc:0.40
# Epoch: 30
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.42
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:12.58 	 Val (with Target) Acc:0.46
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:3.48 	 Test (with Source) Acc:0.56
# Target Domain F:
# 	 Test (with Target) Loss:10.97 	 Test (with Target) Acc:0.35
# Target Domain G:
# 	 Test (with Target) Loss:12.15 	 Test (with Target) Acc:0.46
#
# Phase 3 (Domain G to Domain H)
# Epoch: 1
#  	 Train (with Adv) Loss:0.99 	 Train Acc:0.50
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:11.36 	 Val (with Target) Acc:0.55
# Epoch: 2
#  	 Train (with Adv) Loss:0.97 	 Train Acc:0.44
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:15.44 	 Val (with Target) Acc:0.31
# Epoch: 3
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.31
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:13.35 	 Val (with Target) Acc:0.38
# Epoch: 4
#  	 Train (with Adv) Loss:1.00 	 Train Acc:0.47
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:11.86 	 Val (with Target) Acc:0.53
# Epoch: 5
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.39
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:12.64 	 Val (with Target) Acc:0.45
# Epoch: 6
#  	 Train (with Adv) Loss:0.99 	 Train Acc:0.27
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:16.60 	 Val (with Target) Acc:0.28
# Epoch: 7
#  	 Train (with Adv) Loss:1.00 	 Train Acc:0.41
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:14.27 	 Val (with Target) Acc:0.38
# Epoch: 8
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.26
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:16.19 	 Val (with Target) Acc:0.32
# Epoch: 9
#  	 Train (with Adv) Loss:1.00 	 Train Acc:0.41
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:17.11 	 Val (with Target) Acc:0.25
# Epoch: 10
#  	 Train (with Adv) Loss:0.99 	 Train Acc:0.25
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:15.52 	 Val (with Target) Acc:0.32
# Epoch: 11
#  	 Train (with Adv) Loss:1.02 	 Train Acc:0.25
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:14.36 	 Val (with Target) Acc:0.39
# Epoch: 12
#  	 Train (with Adv) Loss:0.98 	 Train Acc:0.32
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:16.90 	 Val (with Target) Acc:0.25
# Epoch: 13
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.26
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:18.44 	 Val (with Target) Acc:0.22
# Epoch: 14
#  	 Train (with Adv) Loss:0.99 	 Train Acc:0.35
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:17.28 	 Val (with Target) Acc:0.28
# Epoch: 15
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.22
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:18.20 	 Val (with Target) Acc:0.22
# Epoch: 16
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.23
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:15.28 	 Val (with Target) Acc:0.31
# Epoch: 17
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.32
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:17.61 	 Val (with Target) Acc:0.24
# Epoch: 18
#  	 Train (with Adv) Loss:1.02 	 Train Acc:0.23
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:15.81 	 Val (with Target) Acc:0.38
# Epoch: 19
#  	 Train (with Adv) Loss:1.02 	 Train Acc:0.31
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:18.75 	 Val (with Target) Acc:0.21
# Epoch: 20
#  	 Train (with Adv) Loss:1.03 	 Train Acc:0.22
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:17.70 	 Val (with Target) Acc:0.22
# Epoch: 21
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.22
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:16.89 	 Val (with Target) Acc:0.23
# Epoch: 22
#  	 Train (with Adv) Loss:1.02 	 Train Acc:0.23
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:14.73 	 Val (with Target) Acc:0.36
# Epoch: 23
#  	 Train (with Adv) Loss:1.00 	 Train Acc:0.28
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:18.27 	 Val (with Target) Acc:0.21
# Epoch: 24
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.23
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:16.06 	 Val (with Target) Acc:0.26
# Epoch: 25
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.21
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:16.76 	 Val (with Target) Acc:0.28
# Epoch: 26
#  	 Train (with Adv) Loss:1.03 	 Train Acc:0.22
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:15.79 	 Val (with Target) Acc:0.26
# Epoch: 27
#  	 Train (with Adv) Loss:1.02 	 Train Acc:0.22
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:16.74 	 Val (with Target) Acc:0.27
# Epoch: 28
#  	 Train (with Adv) Loss:1.02 	 Train Acc:0.28
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:13.95 	 Val (with Target) Acc:0.45
# Epoch: 29
#  	 Train (with Adv) Loss:1.01 	 Train Acc:0.44
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:15.79 	 Val (with Target) Acc:0.30
# Epoch: 30
#  	 Train (with Adv) Loss:0.99 	 Train Acc:0.23
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:15.21 	 Val (with Target) Acc:0.32
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:3.94 	 Test (with Source) Acc:0.46
# Target Domain F:
# 	 Test (with Target) Loss:10.25 	 Test (with Target) Acc:0.33
# Target Domain G:
# 	 Test (with Target) Loss:13.81 	 Test (with Target) Acc:0.35
# Target Domain H:
# 	 Test (with Target) Loss:15.12 	 Test (with Target) Acc:0.27
#
# Phase 4 (Domain H to Domain A)
# Epoch: 1
#  	 Train (with Adv) Loss:1.41 	 Train Acc:0.17
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:18.29 	 Val (with Target) Acc:0.19
# Epoch: 2
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.15
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:16.28 	 Val (with Target) Acc:0.16
# Epoch: 3
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.13
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:17.77 	 Val (with Target) Acc:0.17
# Epoch: 4
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.12
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:13.09 	 Val (with Target) Acc:0.15
# Epoch: 5
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.16
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:16.65 	 Val (with Target) Acc:0.17
# Epoch: 6
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.16
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:14.39 	 Val (with Target) Acc:0.28
# Epoch: 7
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.17
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:17.67 	 Val (with Target) Acc:0.14
# Epoch: 8
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.11
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:14.35 	 Val (with Target) Acc:0.17
# Epoch: 9
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.16
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.05 	 Val (with Target) Acc:0.12
# Epoch: 10
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.15
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:15.32 	 Val (with Target) Acc:0.15
# Epoch: 11
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.17
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:19.85 	 Val (with Target) Acc:0.18
# Epoch: 12
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.14
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:13.55 	 Val (with Target) Acc:0.20
# Epoch: 13
#  	 Train (with Adv) Loss:1.17 	 Train Acc:0.15
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:20.56 	 Val (with Target) Acc:0.14
# Epoch: 14
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.16
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:19.21 	 Val (with Target) Acc:0.18
# Epoch: 15
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.14
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:13.70 	 Val (with Target) Acc:0.20
# Epoch: 16
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.13
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:18.95 	 Val (with Target) Acc:0.11
# Epoch: 17
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.12
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:19.29 	 Val (with Target) Acc:0.11
# Epoch: 18
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.07
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:15.48 	 Val (with Target) Acc:0.10
# Epoch: 19
#  	 Train (with Adv) Loss:1.17 	 Train Acc:0.11
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:19.07 	 Val (with Target) Acc:0.06
# Epoch: 20
#  	 Train (with Adv) Loss:1.21 	 Train Acc:0.08
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:19.00 	 Val (with Target) Acc:0.07
# Epoch: 21
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.08
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:20.75 	 Val (with Target) Acc:0.08
# Epoch: 22
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.10
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:19.48 	 Val (with Target) Acc:0.06
# Epoch: 23
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.10
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:17.58 	 Val (with Target) Acc:0.10
# Epoch: 24
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.09
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:20.55 	 Val (with Target) Acc:0.05
# Epoch: 25
#  	 Train (with Adv) Loss:1.17 	 Train Acc:0.10
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:22.94 	 Val (with Target) Acc:0.10
# Epoch: 26
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.10
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:15.43 	 Val (with Target) Acc:0.04
# Epoch: 27
#  	 Train (with Adv) Loss:0.90 	 Train Acc:0.11
# 	 Discriminator Loss:1.03 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.29 	 Val (with Target) Acc:0.09
# Epoch: 28
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.09
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:24.57 	 Val (with Target) Acc:0.01
# Epoch: 29
#  	 Train (with Adv) Loss:1.29 	 Train Acc:0.08
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:21.46 	 Val (with Target) Acc:0.10
# Epoch: 30
#  	 Train (with Adv) Loss:1.29 	 Train Acc:0.09
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:23.74 	 Val (with Target) Acc:0.09
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:6.59 	 Test (with Source) Acc:0.30
# Target Domain F:
# 	 Test (with Target) Loss:10.25 	 Test (with Target) Acc:0.33
# Target Domain G:
# 	 Test (with Target) Loss:17.07 	 Test (with Target) Acc:0.36
# Target Domain H:
# 	 Test (with Target) Loss:19.18 	 Test (with Target) Acc:0.36
# Target Domain A:
# 	 Test (with Target) Loss:24.92 	 Test (with Target) Acc:0.10
#
# Phase 5 (Domain A to Domain B)
# Epoch: 1
#  	 Train (with Adv) Loss:1.30 	 Train Acc:0.11
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.70 	 Val (with Target) Acc:0.15
# Epoch: 2
#  	 Train (with Adv) Loss:1.32 	 Train Acc:0.16
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:15.47 	 Val (with Target) Acc:0.10
# Epoch: 3
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.13
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:23.46 	 Val (with Target) Acc:0.20
# Epoch: 4
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.15
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:17.58 	 Val (with Target) Acc:0.12
# Epoch: 5
#  	 Train (with Adv) Loss:1.12 	 Train Acc:0.12
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:25.56 	 Val (with Target) Acc:0.09
# Epoch: 6
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.10
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:23.06 	 Val (with Target) Acc:0.09
# Epoch: 7
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.12
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:24.90 	 Val (with Target) Acc:0.11
# Epoch: 8
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.14
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:22.24 	 Val (with Target) Acc:0.10
# Epoch: 9
#  	 Train (with Adv) Loss:1.17 	 Train Acc:0.13
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:24.19 	 Val (with Target) Acc:0.11
# Epoch: 10
#  	 Train (with Adv) Loss:1.13 	 Train Acc:0.12
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:22.50 	 Val (with Target) Acc:0.11
# Epoch: 11
#  	 Train (with Adv) Loss:1.11 	 Train Acc:0.12
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:23.08 	 Val (with Target) Acc:0.11
# Epoch: 12
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.13
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:20.99 	 Val (with Target) Acc:0.13
# Epoch: 13
#  	 Train (with Adv) Loss:1.13 	 Train Acc:0.14
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:22.74 	 Val (with Target) Acc:0.12
# Epoch: 14
#  	 Train (with Adv) Loss:1.12 	 Train Acc:0.12
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:23.57 	 Val (with Target) Acc:0.11
# Epoch: 15
#  	 Train (with Adv) Loss:1.14 	 Train Acc:0.12
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:22.25 	 Val (with Target) Acc:0.12
# Epoch: 16
#  	 Train (with Adv) Loss:1.14 	 Train Acc:0.12
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:26.67 	 Val (with Target) Acc:0.16
# Epoch: 17
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.14
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:21.40 	 Val (with Target) Acc:0.13
# Epoch: 18
#  	 Train (with Adv) Loss:1.13 	 Train Acc:0.14
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:21.62 	 Val (with Target) Acc:0.12
# Epoch: 19
#  	 Train (with Adv) Loss:1.18 	 Train Acc:0.13
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:21.21 	 Val (with Target) Acc:0.11
# Epoch: 20
#  	 Train (with Adv) Loss:1.13 	 Train Acc:0.15
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:21.62 	 Val (with Target) Acc:0.13
# Epoch: 21
#  	 Train (with Adv) Loss:1.16 	 Train Acc:0.14
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:23.66 	 Val (with Target) Acc:0.13
# Epoch: 22
#  	 Train (with Adv) Loss:1.14 	 Train Acc:0.15
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:22.59 	 Val (with Target) Acc:0.16
# Epoch: 23
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.15
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:22.79 	 Val (with Target) Acc:0.15
# Epoch: 24
#  	 Train (with Adv) Loss:1.17 	 Train Acc:0.15
# 	 Discriminator Loss:0.60 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:20.11 	 Val (with Target) Acc:0.12
# Epoch: 25
#  	 Train (with Adv) Loss:1.19 	 Train Acc:0.15
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:21.78 	 Val (with Target) Acc:0.12
# Epoch: 26
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.13
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:22.23 	 Val (with Target) Acc:0.13
# Epoch: 27
#  	 Train (with Adv) Loss:1.20 	 Train Acc:0.14
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:19.93 	 Val (with Target) Acc:0.14
# Epoch: 28
#  	 Train (with Adv) Loss:1.15 	 Train Acc:0.14
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:20.37 	 Val (with Target) Acc:0.12
# Epoch: 29
#  	 Train (with Adv) Loss:1.16 	 Train Acc:0.12
# 	 Discriminator Loss:0.61 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:21.93 	 Val (with Target) Acc:0.14
# Epoch: 30
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.18
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:22.35 	 Val (with Target) Acc:0.14
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:16.35 	 Test (with Source) Acc:0.33
# Target Domain F:
# 	 Test (with Target) Loss:17.46 	 Test (with Target) Acc:0.21
# Target Domain G:
# 	 Test (with Target) Loss:15.38 	 Test (with Target) Acc:0.17
# Target Domain H:
# 	 Test (with Target) Loss:20.55 	 Test (with Target) Acc:0.25
# Target Domain A:
# 	 Test (with Target) Loss:33.09 	 Test (with Target) Acc:0.14
# Target Domain B:
# 	 Test (with Target) Loss:23.91 	 Test (with Target) Acc:0.13
#
# Phase 6 (Domain B to Domain C)
# Epoch: 1
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.14
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:23.18 	 Val (with Target) Acc:0.17
# Epoch: 2
#  	 Train (with Adv) Loss:1.25 	 Train Acc:0.17
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:20.91 	 Val (with Target) Acc:0.21
# Epoch: 3
#  	 Train (with Adv) Loss:1.23 	 Train Acc:0.18
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:19.35 	 Val (with Target) Acc:0.19
# Epoch: 4
#  	 Train (with Adv) Loss:1.22 	 Train Acc:0.16
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:21.17 	 Val (with Target) Acc:0.17
# Epoch: 5
#  	 Train (with Adv) Loss:1.27 	 Train Acc:0.18
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:21.83 	 Val (with Target) Acc:0.18
# Epoch: 6
#  	 Train (with Adv) Loss:1.28 	 Train Acc:0.15
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:19.69 	 Val (with Target) Acc:0.15
# Epoch: 7
#  	 Train (with Adv) Loss:1.31 	 Train Acc:0.19
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:20.25 	 Val (with Target) Acc:0.15
# Epoch: 8
#  	 Train (with Adv) Loss:1.30 	 Train Acc:0.15
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:20.12 	 Val (with Target) Acc:0.17
# Epoch: 9
#  	 Train (with Adv) Loss:1.30 	 Train Acc:0.17
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:26.08 	 Val (with Target) Acc:0.23
# Epoch: 10
#  	 Train (with Adv) Loss:1.33 	 Train Acc:0.19
# 	 Discriminator Loss:0.52 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:23.79 	 Val (with Target) Acc:0.23
# Epoch: 11
#  	 Train (with Adv) Loss:1.28 	 Train Acc:0.14
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:23.40 	 Val (with Target) Acc:0.17
# Epoch: 12
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.18
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:20.19 	 Val (with Target) Acc:0.14
# Epoch: 13
#  	 Train (with Adv) Loss:1.31 	 Train Acc:0.15
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:23.17 	 Val (with Target) Acc:0.20
# Epoch: 14
#  	 Train (with Adv) Loss:1.35 	 Train Acc:0.19
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.76
# 	 Val (with Target) Loss:23.74 	 Val (with Target) Acc:0.24
# Epoch: 15
#  	 Train (with Adv) Loss:1.31 	 Train Acc:0.15
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:22.14 	 Val (with Target) Acc:0.15
# Epoch: 16
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.17
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:22.69 	 Val (with Target) Acc:0.17
# Epoch: 17
#  	 Train (with Adv) Loss:1.31 	 Train Acc:0.19
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:21.64 	 Val (with Target) Acc:0.16
# Epoch: 18
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.18
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:25.79 	 Val (with Target) Acc:0.18
# Epoch: 19
#  	 Train (with Adv) Loss:1.32 	 Train Acc:0.16
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:21.26 	 Val (with Target) Acc:0.16
# Epoch: 20
#  	 Train (with Adv) Loss:1.34 	 Train Acc:0.15
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:22.16 	 Val (with Target) Acc:0.17
# Epoch: 21
#  	 Train (with Adv) Loss:1.41 	 Train Acc:0.19
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:25.49 	 Val (with Target) Acc:0.24
# Epoch: 22
#  	 Train (with Adv) Loss:1.32 	 Train Acc:0.15
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:23.23 	 Val (with Target) Acc:0.21
# Epoch: 23
#  	 Train (with Adv) Loss:1.30 	 Train Acc:0.13
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:21.68 	 Val (with Target) Acc:0.15
# Epoch: 24
#  	 Train (with Adv) Loss:1.34 	 Train Acc:0.14
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:23.48 	 Val (with Target) Acc:0.16
# Epoch: 25
#  	 Train (with Adv) Loss:1.31 	 Train Acc:0.15
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:24.64 	 Val (with Target) Acc:0.19
# Epoch: 26
#  	 Train (with Adv) Loss:1.35 	 Train Acc:0.17
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:25.99 	 Val (with Target) Acc:0.23
# Epoch: 27
#  	 Train (with Adv) Loss:1.41 	 Train Acc:0.14
# 	 Discriminator Loss:0.51 	 Discriminator Acc:0.77
# 	 Val (with Target) Loss:21.17 	 Val (with Target) Acc:0.14
# Epoch: 28
#  	 Train (with Adv) Loss:1.29 	 Train Acc:0.15
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:21.50 	 Val (with Target) Acc:0.17
# Epoch: 29
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.18
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:25.02 	 Val (with Target) Acc:0.19
# Epoch: 30
#  	 Train (with Adv) Loss:1.32 	 Train Acc:0.17
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:22.27 	 Val (with Target) Acc:0.16
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:8.86 	 Test (with Source) Acc:0.33
# Target Domain F:
# 	 Test (with Target) Loss:14.48 	 Test (with Target) Acc:0.29
# Target Domain G:
# 	 Test (with Target) Loss:13.60 	 Test (with Target) Acc:0.34
# Target Domain H:
# 	 Test (with Target) Loss:19.40 	 Test (with Target) Acc:0.35
# Target Domain A:
# 	 Test (with Target) Loss:28.61 	 Test (with Target) Acc:0.03
# Target Domain B:
# 	 Test (with Target) Loss:23.69 	 Test (with Target) Acc:0.11
# Target Domain C:
# 	 Test (with Target) Loss:25.27 	 Test (with Target) Acc:0.13
#
# Phase 7 (Domain C to Domain D)
# Epoch: 1
#  	 Train (with Adv) Loss:1.35 	 Train Acc:0.14
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:22.55 	 Val (with Target) Acc:0.18
# Epoch: 2
#  	 Train (with Adv) Loss:1.32 	 Train Acc:0.15
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:21.07 	 Val (with Target) Acc:0.17
# Epoch: 3
#  	 Train (with Adv) Loss:1.33 	 Train Acc:0.15
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:19.53 	 Val (with Target) Acc:0.14
# Epoch: 4
#  	 Train (with Adv) Loss:1.32 	 Train Acc:0.15
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:21.91 	 Val (with Target) Acc:0.17
# Epoch: 5
#  	 Train (with Adv) Loss:1.33 	 Train Acc:0.15
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:19.73 	 Val (with Target) Acc:0.14
# Epoch: 6
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.15
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:23.44 	 Val (with Target) Acc:0.17
# Epoch: 7
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.17
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:21.44 	 Val (with Target) Acc:0.15
# Epoch: 8
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.16
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:26.79 	 Val (with Target) Acc:0.17
# Epoch: 9
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.16
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:21.35 	 Val (with Target) Acc:0.17
# Epoch: 10
#  	 Train (with Adv) Loss:1.31 	 Train Acc:0.17
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:19.23 	 Val (with Target) Acc:0.17
# Epoch: 11
#  	 Train (with Adv) Loss:1.34 	 Train Acc:0.18
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:20.55 	 Val (with Target) Acc:0.17
# Epoch: 12
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.16
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:22.95 	 Val (with Target) Acc:0.18
# Epoch: 13
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.16
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:24.79 	 Val (with Target) Acc:0.18
# Epoch: 14
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.17
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:20.94 	 Val (with Target) Acc:0.16
# Epoch: 15
#  	 Train (with Adv) Loss:1.41 	 Train Acc:0.18
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:22.60 	 Val (with Target) Acc:0.19
# Epoch: 16
#  	 Train (with Adv) Loss:1.34 	 Train Acc:0.18
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:20.72 	 Val (with Target) Acc:0.17
# Epoch: 17
#  	 Train (with Adv) Loss:1.34 	 Train Acc:0.16
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:20.47 	 Val (with Target) Acc:0.17
# Epoch: 18
#  	 Train (with Adv) Loss:1.39 	 Train Acc:0.17
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:26.48 	 Val (with Target) Acc:0.17
# Epoch: 19
#  	 Train (with Adv) Loss:1.43 	 Train Acc:0.17
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.76
# 	 Val (with Target) Loss:25.40 	 Val (with Target) Acc:0.18
# Epoch: 20
#  	 Train (with Adv) Loss:1.40 	 Train Acc:0.16
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:21.58 	 Val (with Target) Acc:0.18
# Epoch: 21
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.17
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:20.06 	 Val (with Target) Acc:0.18
# Epoch: 22
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.18
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:19.68 	 Val (with Target) Acc:0.17
# Epoch: 23
#  	 Train (with Adv) Loss:1.41 	 Train Acc:0.17
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:21.26 	 Val (with Target) Acc:0.19
# Epoch: 24
#  	 Train (with Adv) Loss:1.37 	 Train Acc:0.16
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:21.14 	 Val (with Target) Acc:0.17
# Epoch: 25
#  	 Train (with Adv) Loss:1.40 	 Train Acc:0.16
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:24.06 	 Val (with Target) Acc:0.17
# Epoch: 26
#  	 Train (with Adv) Loss:1.41 	 Train Acc:0.15
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:22.92 	 Val (with Target) Acc:0.17
# Epoch: 27
#  	 Train (with Adv) Loss:1.42 	 Train Acc:0.17
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:20.85 	 Val (with Target) Acc:0.18
# Epoch: 28
#  	 Train (with Adv) Loss:1.36 	 Train Acc:0.17
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:20.65 	 Val (with Target) Acc:0.19
# Epoch: 29
#  	 Train (with Adv) Loss:1.38 	 Train Acc:0.16
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.75
# 	 Val (with Target) Loss:19.29 	 Val (with Target) Acc:0.17
# Epoch: 30
#  	 Train (with Adv) Loss:1.35 	 Train Acc:0.16
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:21.95 	 Val (with Target) Acc:0.17
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain E:
# 	 Test (with Source) Loss:9.20 	 Test (with Source) Acc:0.34
# Target Domain F:
# 	 Test (with Target) Loss:16.81 	 Test (with Target) Acc:0.25
# Target Domain G:
# 	 Test (with Target) Loss:15.68 	 Test (with Target) Acc:0.20
# Target Domain H:
# 	 Test (with Target) Loss:21.21 	 Test (with Target) Acc:0.26
# Target Domain A:
# 	 Test (with Target) Loss:30.34 	 Test (with Target) Acc:0.09
# Target Domain B:
# 	 Test (with Target) Loss:26.14 	 Test (with Target) Acc:0.17
# Target Domain C:
# 	 Test (with Target) Loss:26.99 	 Test (with Target) Acc:0.13
# Target Domain D:
# 	 Test (with Target) Loss:24.09 	 Test (with Target) Acc:0.14

# %%
generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_src, "cuda")
src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_tgt[phase], "cuda")
    tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[phase])
    print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# 	 Test (with Source) Loss:9.20 	 Test (with Source) Acc:0.34
#
# Phase 1 (Domain E to Domain F)
# 	 Test (with Target) Loss:16.81 	 Test (with Target) Acc:0.25
#
# Phase 2 (Domain F to Domain G)
# 	 Test (with Target) Loss:15.68 	 Test (with Target) Acc:0.20
#
# Phase 3 (Domain G to Domain H)
# 	 Test (with Target) Loss:21.21 	 Test (with Target) Acc:0.27
#
# Phase 4 (Domain H to Domain A)
# 	 Test (with Target) Loss:30.34 	 Test (with Target) Acc:0.09
#
# Phase 5 (Domain A to Domain B)
# 	 Test (with Target) Loss:26.14 	 Test (with Target) Acc:0.17
#
# Phase 6 (Domain B to Domain C)
# 	 Test (with Target) Loss:26.99 	 Test (with Target) Acc:0.13
#
# Phase 7 (Domain C to Domain D)
# 	 Test (with Target) Loss:24.09 	 Test (with Target) Acc:0.14
