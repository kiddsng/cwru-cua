# %% [markdown]
# ### Continuous Unsupervised Adaptation

# %%
# import modules and libraries
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.autograd import Variable

# functions to create datasets and models
from data.data import *
from models.models import *

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available')
else:
    print('CUDA is available')
    device = torch.device('cuda')
# Out:
# CUDA is available

# %% [markdown]
# ### Parameters

# %%
"""Parameters for this experiment"""
# params for loading the data
path = 'data/CWRU/bearing/'
source_domain = 'A'
target_domains = ['B', 'C', 'D', 'E', 'F', 'G', 'H']

# params for configuring the model
input_dim = 1
hidden_dim = 256
output_dim = 10
drop_prob = 0.5

# params for training the model
epochs_pre = 30 # pre-training
epochs = 30

# optimizing the model
lr = 1e-4
d_lr = 1e-4
batch_size = 20
beta1 = 0.5
beta2 = 0.9
lambda_rpy = 0.03

# %% [markdown]
# ### Data Loading

# %%
# source domain data for training, validating and testing
train_dataloader_src, val_dataloader_src, test_dataloader_src = generate_dataloaders(path, source_domain, batch_size)

# target domain data for validating and testing
train_dataloader_tgt, val_dataloader_tgt, test_dataloader_tgt = [], [], []
for target_domain in target_domains:
    train_dataloader_temp, val_dataloader_temp, test_dataloader_temp = generate_dataloaders(path, target_domain, batch_size)
    
    train_dataloader_tgt.append(train_dataloader_temp)
    val_dataloader_tgt.append(val_dataloader_temp)
    test_dataloader_tgt.append(test_dataloader_temp)

# replay data for CDA
replay_dataset = ReplayDataset(train_dataloader_src.dataset)
replay_dataloader = DataLoader(dataset=replay_dataset, batch_size=batch_size)

# %% [markdown]
# ### Model

# %%
encoder_src = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim # hidden layers 64
)

classifier = Classifier_AMDA(
    hidden_dim=hidden_dim, # hidden layers 64
    output_dim=output_dim, # 3 classes (healthy, inner- and outer-bearing damages)
    dropout=drop_prob # dropout prob 0.5
)

encoder_tgt = Encoder_AMDA(
    input_dim=input_dim, # 1D input (sensor readings)
    hidden_dim=hidden_dim, # hidden layers 64
)

discriminator = Discriminator(
    hidden_dim=hidden_dim
)

if train_on_gpu:
    encoder_src = encoder_src.to(device)
    classifier = classifier.to(device)
    encoder_tgt = encoder_tgt.to(device)
    discriminator = discriminator.to(device)

# %% [markdown]
# #### Functions for training and testing the model

# %%
# functions for training source encoder and shared classifier
def train_src(encoder, classifier):
    """Train the source encoder and shared classifier on source domain"""
    encoder.train()
    classifier.train()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        list(encoder.parameters()) + list(classifier.parameters()),
        lr=lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs_pre):
        accuracies = []
        losses = []

        for batch_idx, (x_src, y_src) in enumerate(train_dataloader_src):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            optimizer.zero_grad()

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            loss_src.backward()

            optimizer.step()

            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')

        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_src(encoder, classifier, phase = 'Val')
        print(f'\t Val Loss:{val_loss:0.2f} \t\t Val Acc:{val_acc:0.2f}')

    return encoder, classifier

# testing model on source domain
def evaluate_src(encoder, classifier, phase='Val'): # phase can be validate or test
    """Evaluate the trained network on source domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    dataloader = val_dataloader_src if phase == 'Val' else test_dataloader_src
    
    with torch.no_grad():
        for batch_idx, (x_src, y_src) in enumerate(dataloader):
            if train_on_gpu:
                x_src, y_src = x_src.to(device), y_src.to(device)

            e_src = encoder(x_src)
            pred_src = classifier(e_src)
            loss_src = criterion(pred_src, y_src)
            
            # append loss for each batch
            losses.append(loss_src.detach().item()) # detach the loss from compute graph 
            accuracies.append(y_src.eq(pred_src.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# Continuous Unsupervised Adaptation (CUA)
# functions for training target encoder
def train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase):
    """Train the target encoder on target domains with source encoder and test the network"""
    encoder_tgt.train()
    discriminator.train()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(
        encoder_tgt.parameters(),
        lr=lr,
        betas=(beta1, beta2)
    )
    d_optimizer = Adam(
        discriminator.parameters(),
        lr=d_lr,
        betas=(beta1, beta2)
    )

    for epoch in range(epochs):
        losses = []
        losses_d = []
        losses_tgt = []
        losses_rpy = []
        accuracies = []
        accuracies_d = []

        for batch_idx, ((x_src, y_src), (x_tgt, y_tgt), (x_rpy, y_rpy)) in enumerate(zip(train_dataloader_src, train_dataloader_tgt[phase], replay_dataloader)):
            if(train_on_gpu):
                x_src, y_src = x_src.to(device), y_src.to(device)
                x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)
                x_rpy, y_rpy = x_rpy.to(device), y_rpy.to(device)

            optimizer.zero_grad()
            d_optimizer.zero_grad()

            # part 1: sequential unsupervised adaptation
            # learn e_src and _tgt: source and target mapping represenations
            e_src = encoder_src(x_src)
            e_tgt = encoder_tgt(x_tgt)
            e_concat = torch.concat((e_src.detach(), e_tgt.detach()), 0)
            # minimize distance between source and target empirical mapping distribution using adversarial discriminator
            d_concat = discriminator(e_concat)

            label_src = Variable(torch.ones(e_src.size(0)).long()).to(device)
            label_tgt = Variable(torch.zeros(e_tgt.size(0)).long()).to(device)
            label_concat = torch.cat((label_src, label_tgt), 0)

            loss_d = criterion(d_concat, label_concat)
            loss_d.backward()
            d_optimizer.step()

            e_tgt = encoder_tgt(x_tgt)
            pred_tgt = classifier(e_tgt)
            d_tgt = discriminator(e_tgt)
            label_tgt = Variable(torch.ones(e_tgt.size(0)).long()).to(device)
            loss_tgt = criterion(d_tgt, label_tgt)

            # part 2: continuous replay adaptation
            # additional replay loss to retain 'prior knowledge'
            pred_rpy = classifier(encoder_tgt(x_rpy))
            loss_rpy = criterion(pred_rpy, y_rpy)
            loss = loss_tgt + lambda_rpy * loss_rpy
            loss.backward()

            optimizer.step()

            # training (with replay) losses and accuracies
            losses.append(loss.detach().item()) # detach the loss from compute graph
            losses_d.append(loss_d.detach().item())
            losses_tgt.append(loss_tgt.detach().item())
            losses_rpy.append(loss_rpy.detach().item())
            accuracies.append(y_tgt.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            accuracies_d.append(torch.squeeze(d_concat.max(1)[1]).eq(label_concat.detach()).float().mean())
        
        # print for each epoch
        print(f'Epoch: {epoch + 1} \n \t Train Loss:{torch.tensor(losses).mean():0.2f} \t Train Acc:{torch.tensor(accuracies).mean():0.2f}')
        print(f'\t Train (Adv) Loss:{torch.tensor(losses_tgt).mean():0.2f} \t Train (Replay) Loss:{torch.tensor(losses_rpy).mean():0.2f}')
        print(f'\t Discriminator Loss:{torch.tensor(losses_d).mean():0.2f} \t Discriminator Acc:{torch.tensor(accuracies_d).mean():0.2f}')
        
        # for each epoch, evaluate your model on the validation data
        val_loss, val_acc = evaluate_tgt(encoder_tgt, classifier, val_dataloader_tgt[phase])
        print(f'\t Val (with Target) Loss:{val_loss:0.2f} \t Val (with Target) Acc:{val_acc:0.2f}')

    return encoder_tgt
    
# testing model on target domains
def evaluate_tgt(encoder, classifier, dataloader):
    """Evaluate the network on current target domain"""
    encoder.eval()
    classifier.eval()

    criterion = nn.CrossEntropyLoss()
    
    losses = []
    accuracies = []
    
    with torch.no_grad():
        for batch_idx, (x, y) in enumerate(dataloader): # target dataloader
            if(train_on_gpu):
                x, y = x.to(device), y.to(device)

            pred_tgt = classifier(encoder(x))
            loss_tgt = criterion(pred_tgt, y)
            
            # append loss for each batch
            losses.append(loss_tgt.detach().item()) # detach the loss from compute graph 
            accuracies.append(y.eq(pred_tgt.detach().argmax(dim=1)).float().mean())
            
        mean_loss = torch.tensor(losses).mean()
        mean_acc = torch.tensor(accuracies).mean()
        return mean_loss, mean_acc

# %%
# subsample previously seen examples and their respective classification scores as 'soft labels' from the target domains
def generate_data_tuple(encoder_tgt, classifier, dataloader):
    print('===> generate new replay dataset!')
    encoder_tgt.eval()
    classifier.eval()

    all_x, all_pred = [], []
    for batch_idx, (x_tgt, y_tgt) in enumerate(dataloader):
        if(train_on_gpu):
            x_tgt, y_tgt = x_tgt.to(device), y_tgt.to(device)

        # perform classification with the target mapping representations
        pred_tgt = classifier(encoder_tgt(x_tgt))

        all_x.append(to_np(x_tgt))
        all_pred.append(to_np(pred_tgt.detach().argmax(dim=1)))
        
    x, pred = np.concatenate(all_x, 0), np.concatenate(all_pred, 0)
    print('generated: ', x.shape, pred.shape)
    return x, pred

# %% [markdown]
# ### Pre-training

# %%
# pre-training
encoder_src, classifier = train_src(encoder_src, classifier)
torch.save(encoder_src.state_dict(), './dump/source_encoder_cwru_cua.pt')
torch.save(classifier.state_dict(), './dump/classifier_cwru_cua.pt')
# encoder_src.load_state_dict(torch.load('./dump/source_encoder_cwru_cua.pt'))
# classifier.load_state_dict(torch.load('./dump/classifier_cwru_cua.pt'))
# Out:
# Epoch: 1
#  	 Train Loss:2.24 	 Train Acc:0.12
# 	 Val Loss:2.08 		 Val Acc:0.11
# Epoch: 2
#  	 Train Loss:1.90 	 Train Acc:0.26
# 	 Val Loss:1.70 		 Val Acc:0.50
# Epoch: 3
#  	 Train Loss:1.42 	 Train Acc:0.63
# 	 Val Loss:1.16 		 Val Acc:0.67
# Epoch: 4
#  	 Train Loss:0.97 	 Train Acc:0.73
# 	 Val Loss:0.83 		 Val Acc:0.82
# Epoch: 5
#  	 Train Loss:0.71 	 Train Acc:0.83
# 	 Val Loss:0.64 		 Val Acc:0.85
# Epoch: 6
#  	 Train Loss:0.55 	 Train Acc:0.86
# 	 Val Loss:0.51 		 Val Acc:0.84
# Epoch: 7
#  	 Train Loss:0.44 	 Train Acc:0.89
# 	 Val Loss:0.41 		 Val Acc:0.91
# Epoch: 8
#  	 Train Loss:0.36 	 Train Acc:0.90
# 	 Val Loss:0.33 		 Val Acc:0.91
# Epoch: 9
#  	 Train Loss:0.30 	 Train Acc:0.92
# 	 Val Loss:0.27 		 Val Acc:0.94
# Epoch: 10
#  	 Train Loss:0.25 	 Train Acc:0.93
# 	 Val Loss:0.24 		 Val Acc:0.93
# Epoch: 11
#  	 Train Loss:0.21 	 Train Acc:0.94
# 	 Val Loss:0.22 		 Val Acc:0.91
# Epoch: 12
#  	 Train Loss:0.18 	 Train Acc:0.95
# 	 Val Loss:0.16 		 Val Acc:0.96
# Epoch: 13
#  	 Train Loss:0.15 	 Train Acc:0.96
# 	 Val Loss:0.14 		 Val Acc:0.97
# Epoch: 14
#  	 Train Loss:0.12 	 Train Acc:0.97
# 	 Val Loss:0.12 		 Val Acc:0.97
# Epoch: 15
#  	 Train Loss:0.12 	 Train Acc:0.97
# 	 Val Loss:0.10 		 Val Acc:0.98
# Epoch: 16
#  	 Train Loss:0.09 	 Train Acc:0.98
# 	 Val Loss:0.16 		 Val Acc:0.96
# Epoch: 17
#  	 Train Loss:0.08 	 Train Acc:0.98
# 	 Val Loss:0.07 		 Val Acc:0.98
# Epoch: 18
#  	 Train Loss:0.08 	 Train Acc:0.98
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 19
#  	 Train Loss:0.07 	 Train Acc:0.98
# 	 Val Loss:0.09 		 Val Acc:0.97
# Epoch: 20
#  	 Train Loss:0.07 	 Train Acc:0.98
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 21
#  	 Train Loss:0.07 	 Train Acc:0.98
# 	 Val Loss:0.06 		 Val Acc:0.99
# Epoch: 22
#  	 Train Loss:0.06 	 Train Acc:0.98
# 	 Val Loss:0.06 		 Val Acc:0.98
# Epoch: 23
#  	 Train Loss:0.06 	 Train Acc:0.98
# 	 Val Loss:0.04 		 Val Acc:0.99
# Epoch: 24
#  	 Train Loss:0.05 	 Train Acc:0.99
# 	 Val Loss:0.05 		 Val Acc:0.99
# Epoch: 25
#  	 Train Loss:0.05 	 Train Acc:0.99
# 	 Val Loss:0.04 		 Val Acc:0.99
# Epoch: 26
#  	 Train Loss:0.05 	 Train Acc:0.99
# 	 Val Loss:0.05 		 Val Acc:0.98
# Epoch: 27
#  	 Train Loss:0.05 	 Train Acc:0.98
# 	 Val Loss:0.05 		 Val Acc:0.99
# Epoch: 28
#  	 Train Loss:0.05 	 Train Acc:0.99
# 	 Val Loss:0.05 		 Val Acc:0.99
# Epoch: 29
#  	 Train Loss:0.04 	 Train Acc:0.99
# 	 Val Loss:0.03 		 Val Acc:0.99
# Epoch: 30
#  	 Train Loss:0.04 	 Train Acc:0.99
# 	 Val Loss:0.04 		 Val Acc:0.99

# %%
encoder_tgt.load_state_dict(encoder_src.state_dict())

# adaptation
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    encoder_tgt = train_tgt(encoder_src, encoder_tgt, classifier, discriminator, phase)
    
    print('\nTesting Accuracy on Previously Seen and Current Domains:')
    print(f'Source Domain {source_domain}:')
    src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
    print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
    for p in range(phase + 1):
        print(f'Target Domain {target_domains[p]}:')
        tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[p])
        print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')

    # update replay data and dataloader
    data_tuple = generate_data_tuple(encoder_tgt, classifier, train_dataloader_tgt[phase])
    replay_dataset.replay_dataset.update(data_tuple)
    print(replay_dataset.__len__())
    replay_dataloader = DataLoader(dataset=replay_dataset, batch_size=batch_size)
# Out:
# Phase 1 (Domain A to Domain B)
# Epoch: 1
#  	 Train Loss:0.62 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.61 	 Train (Replay) Loss:0.25
# 	 Discriminator Loss:1.41 	 Discriminator Acc:0.25
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.91
# Epoch: 2
#  	 Train Loss:0.86 	 Train Acc:0.70
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.42
# 	 Discriminator Loss:0.80 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.80 	 Val (with Target) Acc:0.77
# Epoch: 3
#  	 Train Loss:0.77 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.77 	 Train (Replay) Loss:0.15
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.99 	 Val (with Target) Acc:0.67
# Epoch: 4
#  	 Train Loss:0.73 	 Train Acc:0.76
# 	 Train (Adv) Loss:0.72 	 Train (Replay) Loss:0.27
# 	 Discriminator Loss:0.79 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:2.12 	 Val (with Target) Acc:0.47
# Epoch: 5
#  	 Train Loss:0.77 	 Train Acc:0.76
# 	 Train (Adv) Loss:0.76 	 Train (Replay) Loss:0.27
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.56
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.83
# Epoch: 6
#  	 Train Loss:0.76 	 Train Acc:0.76
# 	 Train (Adv) Loss:0.75 	 Train (Replay) Loss:0.30
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.82
# Epoch: 7
#  	 Train Loss:0.78 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.77 	 Train (Replay) Loss:0.22
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.41 	 Val (with Target) Acc:0.87
# Epoch: 8
#  	 Train Loss:0.78 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.77 	 Train (Replay) Loss:0.24
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.62 	 Val (with Target) Acc:0.75
# Epoch: 9
#  	 Train Loss:0.78 	 Train Acc:0.77
# 	 Train (Adv) Loss:0.77 	 Train (Replay) Loss:0.27
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.37 	 Val (with Target) Acc:0.90
# Epoch: 10
#  	 Train Loss:0.81 	 Train Acc:0.77
# 	 Train (Adv) Loss:0.80 	 Train (Replay) Loss:0.29
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.90
# Epoch: 11
#  	 Train Loss:0.82 	 Train Acc:0.88
# 	 Train (Adv) Loss:0.82 	 Train (Replay) Loss:0.15
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.37 	 Val (with Target) Acc:0.86
# Epoch: 12
#  	 Train Loss:0.89 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.27
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.66 	 Val (with Target) Acc:0.78
# Epoch: 13
#  	 Train Loss:0.88 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.16
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.24 	 Val (with Target) Acc:0.92
# Epoch: 14
#  	 Train Loss:0.86 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.20
# 	 Discriminator Loss:0.78 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.48 	 Val (with Target) Acc:0.79
# Epoch: 15
#  	 Train Loss:0.87 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.21
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.25 	 Val (with Target) Acc:0.91
# Epoch: 16
#  	 Train Loss:0.87 	 Train Acc:0.85
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.23
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.31 	 Val (with Target) Acc:0.91
# Epoch: 17
#  	 Train Loss:0.89 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.17
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.91 	 Val (with Target) Acc:0.70
# Epoch: 18
#  	 Train Loss:0.91 	 Train Acc:0.79
# 	 Train (Adv) Loss:0.90 	 Train (Replay) Loss:0.29
# 	 Discriminator Loss:0.78 	 Discriminator Acc:0.47
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.86
# Epoch: 19
#  	 Train Loss:0.87 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.26
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.32 	 Val (with Target) Acc:0.89
# Epoch: 20
#  	 Train Loss:0.88 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.19
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:1.04 	 Val (with Target) Acc:0.67
# Epoch: 21
#  	 Train Loss:0.89 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.22
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.52 	 Val (with Target) Acc:0.80
# Epoch: 22
#  	 Train Loss:0.88 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.17
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.30 	 Val (with Target) Acc:0.87
# Epoch: 23
#  	 Train Loss:0.87 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.21
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.75 	 Val (with Target) Acc:0.81
# Epoch: 24
#  	 Train Loss:0.90 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.23
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.37 	 Val (with Target) Acc:0.83
# Epoch: 25
#  	 Train Loss:0.87 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.19
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.29 	 Val (with Target) Acc:0.91
# Epoch: 26
#  	 Train Loss:0.85 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.21
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.52 	 Val (with Target) Acc:0.82
# Epoch: 27
#  	 Train Loss:0.87 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.22
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.92
# Epoch: 28
#  	 Train Loss:0.89 	 Train Acc:0.85
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.22
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.81
# Epoch: 29
#  	 Train Loss:0.85 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.25
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.82 	 Val (with Target) Acc:0.77
# Epoch: 30
#  	 Train Loss:0.89 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.18
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.46 	 Val (with Target) Acc:0.81
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.15 	 Test (with Source) Acc:0.94
# Target Domain B:
# 	 Test (with Target) Loss:0.40 	 Test (with Target) Acc:0.83
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 4800
#
# Phase 2 (Domain B to Domain C)
# Epoch: 1
#  	 Train Loss:0.89 	 Train Acc:0.74
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.43
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.83 	 Val (with Target) Acc:0.74
# Epoch: 2
#  	 Train Loss:0.87 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.38
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.34 	 Val (with Target) Acc:0.86
# Epoch: 3
#  	 Train Loss:0.90 	 Train Acc:0.79
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.45
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:1.03 	 Val (with Target) Acc:0.69
# Epoch: 4
#  	 Train Loss:0.87 	 Train Acc:0.79
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.38
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:2.07 	 Val (with Target) Acc:0.69
# Epoch: 5
#  	 Train Loss:0.85 	 Train Acc:0.78
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.38
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.61 	 Val (with Target) Acc:0.78
# Epoch: 6
#  	 Train Loss:0.89 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.43
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.85 	 Val (with Target) Acc:0.71
# Epoch: 7
#  	 Train Loss:0.90 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.36
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.34 	 Val (with Target) Acc:0.87
# Epoch: 8
#  	 Train Loss:0.88 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.37
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.67 	 Val (with Target) Acc:0.82
# Epoch: 9
#  	 Train Loss:0.90 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.46
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.54
# 	 Val (with Target) Loss:0.87 	 Val (with Target) Acc:0.77
# Epoch: 10
#  	 Train Loss:0.86 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.55
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.31 	 Val (with Target) Acc:0.89
# Epoch: 11
#  	 Train Loss:0.88 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.52
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.61 	 Val (with Target) Acc:0.80
# Epoch: 12
#  	 Train Loss:0.88 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.38
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.36 	 Val (with Target) Acc:0.87
# Epoch: 13
#  	 Train Loss:0.89 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.43 	 Val (with Target) Acc:0.84
# Epoch: 14
#  	 Train Loss:0.92 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.90 	 Train (Replay) Loss:0.51
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:1.98 	 Val (with Target) Acc:0.61
# Epoch: 15
#  	 Train Loss:0.90 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:1.01 	 Val (with Target) Acc:0.71
# Epoch: 16
#  	 Train Loss:0.90 	 Train Acc:0.78
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.46
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.54 	 Val (with Target) Acc:0.82
# Epoch: 17
#  	 Train Loss:0.90 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.47
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.51 	 Val (with Target) Acc:0.81
# Epoch: 18
#  	 Train Loss:0.85 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.83 	 Train (Replay) Loss:0.46
# 	 Discriminator Loss:0.77 	 Discriminator Acc:0.46
# 	 Val (with Target) Loss:0.40 	 Val (with Target) Acc:0.86
# Epoch: 19
#  	 Train Loss:0.90 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.42
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.71 	 Val (with Target) Acc:0.79
# Epoch: 20
#  	 Train Loss:0.89 	 Train Acc:0.78
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.58
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.62 	 Val (with Target) Acc:0.76
# Epoch: 21
#  	 Train Loss:0.89 	 Train Acc:0.80
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.48
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:1.26 	 Val (with Target) Acc:0.66
# Epoch: 22
#  	 Train Loss:0.93 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.92 	 Train (Replay) Loss:0.48
# 	 Discriminator Loss:0.70 	 Discriminator Acc:0.55
# 	 Val (with Target) Loss:1.04 	 Val (with Target) Acc:0.68
# Epoch: 23
#  	 Train Loss:0.88 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.45
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.34 	 Val (with Target) Acc:0.84
# Epoch: 24
#  	 Train Loss:0.88 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.54
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.34 	 Val (with Target) Acc:0.87
# Epoch: 25
#  	 Train Loss:0.89 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.49
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.34 	 Val (with Target) Acc:0.90
# Epoch: 26
#  	 Train Loss:0.87 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.46
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.42 	 Val (with Target) Acc:0.86
# Epoch: 27
#  	 Train Loss:0.90 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.47
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.86
# Epoch: 28
#  	 Train Loss:0.91 	 Train Acc:0.81
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.61
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.28 	 Val (with Target) Acc:0.91
# Epoch: 29
#  	 Train Loss:0.90 	 Train Acc:0.85
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.59
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.85 	 Val (with Target) Acc:0.79
# Epoch: 30
#  	 Train Loss:0.88 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.44
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.86 	 Val (with Target) Acc:0.65
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.64 	 Test (with Source) Acc:0.78
# Target Domain B:
# 	 Test (with Target) Loss:1.26 	 Test (with Target) Acc:0.55
# Target Domain C:
# 	 Test (with Target) Loss:0.79 	 Test (with Target) Acc:0.66
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 7200
#
# Phase 3 (Domain C to Domain D)
# Epoch: 1
#  	 Train Loss:0.88 	 Train Acc:0.90
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.69
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.37 	 Val (with Target) Acc:0.84
# Epoch: 2
#  	 Train Loss:0.89 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.58
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:2.58 	 Val (with Target) Acc:0.56
# Epoch: 3
#  	 Train Loss:0.89 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.59
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.84
# Epoch: 4
#  	 Train Loss:0.89 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.55 	 Val (with Target) Acc:0.79
# Epoch: 5
#  	 Train Loss:0.88 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.57
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.47
# 	 Val (with Target) Loss:0.39 	 Val (with Target) Acc:0.84
# Epoch: 6
#  	 Train Loss:0.91 	 Train Acc:0.90
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.64
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.65 	 Val (with Target) Acc:0.77
# Epoch: 7
#  	 Train Loss:0.88 	 Train Acc:0.87
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.53
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.47
# 	 Val (with Target) Loss:0.24 	 Val (with Target) Acc:0.91
# Epoch: 8
#  	 Train Loss:0.89 	 Train Acc:0.87
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.56
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.38 	 Val (with Target) Acc:0.85
# Epoch: 9
#  	 Train Loss:0.89 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.72
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:1.03 	 Val (with Target) Acc:0.63
# Epoch: 10
#  	 Train Loss:0.89 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.88 	 Train (Replay) Loss:0.65
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.50 	 Val (with Target) Acc:0.80
# Epoch: 11
#  	 Train Loss:0.87 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.52
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.21 	 Val (with Target) Acc:0.93
# Epoch: 12
#  	 Train Loss:0.87 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.54
# 	 Discriminator Loss:0.76 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:1.09 	 Val (with Target) Acc:0.73
# Epoch: 13
#  	 Train Loss:0.88 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.57
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.68 	 Val (with Target) Acc:0.73
# Epoch: 14
#  	 Train Loss:0.87 	 Train Acc:0.82
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.53
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.29 	 Val (with Target) Acc:0.89
# Epoch: 15
#  	 Train Loss:0.88 	 Train Acc:0.85
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.59
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.39 	 Val (with Target) Acc:0.83
# Epoch: 16
#  	 Train Loss:0.87 	 Train Acc:0.84
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.54
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.55 	 Val (with Target) Acc:0.79
# Epoch: 17
#  	 Train Loss:0.87 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.55
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.32 	 Val (with Target) Acc:0.88
# Epoch: 18
#  	 Train Loss:0.88 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.53
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.50
# 	 Val (with Target) Loss:0.23 	 Val (with Target) Acc:0.93
# Epoch: 19
#  	 Train Loss:0.87 	 Train Acc:0.87
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.64
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.30 	 Val (with Target) Acc:0.89
# Epoch: 20
#  	 Train Loss:0.85 	 Train Acc:0.87
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.48
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.22 	 Val (with Target) Acc:0.91
# Epoch: 21
#  	 Train Loss:0.86 	 Train Acc:0.87
# 	 Train (Adv) Loss:0.84 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.29 	 Val (with Target) Acc:0.89
# Epoch: 22
#  	 Train Loss:0.89 	 Train Acc:0.90
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.54
# 	 Discriminator Loss:0.71 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.53 	 Val (with Target) Acc:0.81
# Epoch: 23
#  	 Train Loss:0.84 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.83 	 Train (Replay) Loss:0.57
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.33 	 Val (with Target) Acc:0.86
# Epoch: 24
#  	 Train Loss:0.87 	 Train Acc:0.85
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.50
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.49
# 	 Val (with Target) Loss:0.27 	 Val (with Target) Acc:0.89
# Epoch: 25
#  	 Train Loss:0.87 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.60
# 	 Discriminator Loss:0.75 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.29 	 Val (with Target) Acc:0.88
# Epoch: 26
#  	 Train Loss:0.87 	 Train Acc:0.87
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.63
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.54 	 Val (with Target) Acc:0.83
# Epoch: 27
#  	 Train Loss:0.87 	 Train Acc:0.83
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.57
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.51
# 	 Val (with Target) Loss:0.47 	 Val (with Target) Acc:0.80
# Epoch: 28
#  	 Train Loss:0.87 	 Train Acc:0.86
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.52
# 	 Discriminator Loss:0.73 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:0.41 	 Val (with Target) Acc:0.82
# Epoch: 29
#  	 Train Loss:0.85 	 Train Acc:0.88
# 	 Train (Adv) Loss:0.83 	 Train (Replay) Loss:0.53
# 	 Discriminator Loss:0.74 	 Discriminator Acc:0.48
# 	 Val (with Target) Loss:0.43 	 Val (with Target) Acc:0.82
# Epoch: 30
#  	 Train Loss:0.87 	 Train Acc:0.90
# 	 Train (Adv) Loss:0.85 	 Train (Replay) Loss:0.55
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.52
# 	 Val (with Target) Loss:0.53 	 Val (with Target) Acc:0.77
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.30 	 Test (with Source) Acc:0.90
# Target Domain B:
# 	 Test (with Target) Loss:0.98 	 Test (with Target) Acc:0.69
# Target Domain C:
# 	 Test (with Target) Loss:1.04 	 Test (with Target) Acc:0.69
# Target Domain D:
# 	 Test (with Target) Loss:0.42 	 Test (with Target) Acc:0.80
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 9600
#
# Phase 4 (Domain D to Domain E)
# Epoch: 1
#  	 Train Loss:0.89 	 Train Acc:0.32
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.52
# 	 Discriminator Loss:0.72 	 Discriminator Acc:0.53
# 	 Val (with Target) Loss:39.74 	 Val (with Target) Acc:0.36
# Epoch: 2
#  	 Train Loss:0.93 	 Train Acc:0.34
# 	 Train (Adv) Loss:0.91 	 Train (Replay) Loss:0.55
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:36.45 	 Val (with Target) Acc:0.32
# Epoch: 3
#  	 Train Loss:0.89 	 Train Acc:0.28
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.65
# 	 Discriminator Loss:0.68 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:36.25 	 Val (with Target) Acc:0.25
# Epoch: 4
#  	 Train Loss:0.89 	 Train Acc:0.26
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.55
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.57
# 	 Val (with Target) Loss:36.67 	 Val (with Target) Acc:0.26
# Epoch: 5
#  	 Train Loss:0.88 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.66
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:36.43 	 Val (with Target) Acc:0.26
# Epoch: 6
#  	 Train Loss:0.88 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.86 	 Train (Replay) Loss:0.65
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.58
# 	 Val (with Target) Loss:37.98 	 Val (with Target) Acc:0.24
# Epoch: 7
#  	 Train Loss:0.92 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.71
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:38.47 	 Val (with Target) Acc:0.25
# Epoch: 8
#  	 Train Loss:0.89 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.87 	 Train (Replay) Loss:0.62
# 	 Discriminator Loss:0.67 	 Discriminator Acc:0.59
# 	 Val (with Target) Loss:37.84 	 Val (with Target) Acc:0.24
# Epoch: 9
#  	 Train Loss:0.91 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.67
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:38.23 	 Val (with Target) Acc:0.24
# Epoch: 10
#  	 Train Loss:0.92 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.73
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:38.57 	 Val (with Target) Acc:0.24
# Epoch: 11
#  	 Train Loss:0.91 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.89 	 Train (Replay) Loss:0.72
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:39.48 	 Val (with Target) Acc:0.24
# Epoch: 12
#  	 Train Loss:0.93 	 Train Acc:0.25
# 	 Train (Adv) Loss:0.91 	 Train (Replay) Loss:0.79
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.60
# 	 Val (with Target) Loss:40.11 	 Val (with Target) Acc:0.28
# Epoch: 13
#  	 Train Loss:0.92 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.90 	 Train (Replay) Loss:0.75
# 	 Discriminator Loss:0.66 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:40.26 	 Val (with Target) Acc:0.30
# Epoch: 14
#  	 Train Loss:0.95 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.92 	 Train (Replay) Loss:0.75
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:39.72 	 Val (with Target) Acc:0.22
# Epoch: 15
#  	 Train Loss:0.94 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.92 	 Train (Replay) Loss:0.73
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:39.45 	 Val (with Target) Acc:0.24
# Epoch: 16
#  	 Train Loss:0.94 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.92 	 Train (Replay) Loss:0.84
# 	 Discriminator Loss:0.65 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:40.47 	 Val (with Target) Acc:0.22
# Epoch: 17
#  	 Train Loss:0.96 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.94 	 Train (Replay) Loss:0.77
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:40.67 	 Val (with Target) Acc:0.22
# Epoch: 18
#  	 Train Loss:0.96 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.94 	 Train (Replay) Loss:0.90
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:41.00 	 Val (with Target) Acc:0.33
# Epoch: 19
#  	 Train Loss:0.96 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.94 	 Train (Replay) Loss:0.82
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:41.12 	 Val (with Target) Acc:0.23
# Epoch: 20
#  	 Train Loss:0.96 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.93 	 Train (Replay) Loss:0.88
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:41.19 	 Val (with Target) Acc:0.21
# Epoch: 21
#  	 Train Loss:0.99 	 Train Acc:0.23
# 	 Train (Adv) Loss:0.96 	 Train (Replay) Loss:0.84
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:40.62 	 Val (with Target) Acc:0.22
# Epoch: 22
#  	 Train Loss:0.97 	 Train Acc:0.25
# 	 Train (Adv) Loss:0.94 	 Train (Replay) Loss:0.99
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:41.00 	 Val (with Target) Acc:0.25
# Epoch: 23
#  	 Train Loss:0.97 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.95 	 Train (Replay) Loss:0.89
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.61
# 	 Val (with Target) Loss:40.95 	 Val (with Target) Acc:0.27
# Epoch: 24
#  	 Train Loss:0.96 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.94 	 Train (Replay) Loss:0.83
# 	 Discriminator Loss:0.64 	 Discriminator Acc:0.62
# 	 Val (with Target) Loss:41.91 	 Val (with Target) Acc:0.25
# Epoch: 25
#  	 Train Loss:1.01 	 Train Acc:0.24
# 	 Train (Adv) Loss:0.98 	 Train (Replay) Loss:0.97
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:41.57 	 Val (with Target) Acc:0.27
# Epoch: 26
#  	 Train Loss:1.00 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.97 	 Train (Replay) Loss:0.81
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.63
# 	 Val (with Target) Loss:41.45 	 Val (with Target) Acc:0.21
# Epoch: 27
#  	 Train Loss:1.00 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.98 	 Train (Replay) Loss:0.77
# 	 Discriminator Loss:0.62 	 Discriminator Acc:0.65
# 	 Val (with Target) Loss:42.12 	 Val (with Target) Acc:0.26
# Epoch: 28
#  	 Train Loss:0.99 	 Train Acc:0.22
# 	 Train (Adv) Loss:0.97 	 Train (Replay) Loss:0.83
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:42.58 	 Val (with Target) Acc:0.19
# Epoch: 29
#  	 Train Loss:1.01 	 Train Acc:0.19
# 	 Train (Adv) Loss:0.98 	 Train (Replay) Loss:0.98
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:42.93 	 Val (with Target) Acc:0.22
# Epoch: 30
#  	 Train Loss:1.03 	 Train Acc:0.20
# 	 Train (Adv) Loss:1.00 	 Train (Replay) Loss:0.87
# 	 Discriminator Loss:0.63 	 Discriminator Acc:0.64
# 	 Val (with Target) Loss:42.81 	 Val (with Target) Acc:0.20
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:0.72 	 Test (with Source) Acc:0.80
# Target Domain B:
# 	 Test (with Target) Loss:1.00 	 Test (with Target) Acc:0.64
# Target Domain C:
# 	 Test (with Target) Loss:1.43 	 Test (with Target) Acc:0.59
# Target Domain D:
# 	 Test (with Target) Loss:0.44 	 Test (with Target) Acc:0.81
# Target Domain E:
# 	 Test (with Target) Loss:56.42 	 Test (with Target) Acc:0.18
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 12000
#
# Phase 5 (Domain E to Domain F)
# Epoch: 1
#  	 Train Loss:1.09 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:1.36
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:44.76 	 Val (with Target) Acc:0.20
# Epoch: 2
#  	 Train Loss:1.06 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.03 	 Train (Replay) Loss:1.09
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:44.61 	 Val (with Target) Acc:0.23
# Epoch: 3
#  	 Train Loss:1.06 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.01 	 Train (Replay) Loss:1.41
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:45.26 	 Val (with Target) Acc:0.27
# Epoch: 4
#  	 Train Loss:1.05 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.26
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:46.29 	 Val (with Target) Acc:0.25
# Epoch: 5
#  	 Train Loss:1.07 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.02 	 Train (Replay) Loss:1.58
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:45.83 	 Val (with Target) Acc:0.19
# Epoch: 6
#  	 Train Loss:1.12 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.06 	 Train (Replay) Loss:1.96
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:47.42 	 Val (with Target) Acc:0.23
# Epoch: 7
#  	 Train Loss:1.10 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.05 	 Train (Replay) Loss:1.87
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:48.60 	 Val (with Target) Acc:0.21
# Epoch: 8
#  	 Train Loss:1.12 	 Train Acc:0.21
# 	 Train (Adv) Loss:1.07 	 Train (Replay) Loss:1.78
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:51.28 	 Val (with Target) Acc:0.20
# Epoch: 9
#  	 Train Loss:1.15 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.08 	 Train (Replay) Loss:2.02
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:52.85 	 Val (with Target) Acc:0.21
# Epoch: 10
#  	 Train Loss:1.15 	 Train Acc:0.21
# 	 Train (Adv) Loss:1.10 	 Train (Replay) Loss:1.92
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:53.00 	 Val (with Target) Acc:0.20
# Epoch: 11
#  	 Train Loss:1.18 	 Train Acc:0.21
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:2.05
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:53.34 	 Val (with Target) Acc:0.24
# Epoch: 12
#  	 Train Loss:1.18 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:2.04
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:54.54 	 Val (with Target) Acc:0.20
# Epoch: 13
#  	 Train Loss:1.14 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.08 	 Train (Replay) Loss:2.06
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:56.60 	 Val (with Target) Acc:0.22
# Epoch: 14
#  	 Train Loss:1.18 	 Train Acc:0.21
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:2.24
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:56.59 	 Val (with Target) Acc:0.22
# Epoch: 15
#  	 Train Loss:1.18 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:2.15
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:56.95 	 Val (with Target) Acc:0.24
# Epoch: 16
#  	 Train Loss:1.18 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:2.26
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:59.09 	 Val (with Target) Acc:0.26
# Epoch: 17
#  	 Train Loss:1.18 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:2.11
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:58.59 	 Val (with Target) Acc:0.24
# Epoch: 18
#  	 Train Loss:1.21 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.14 	 Train (Replay) Loss:2.16
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:58.11 	 Val (with Target) Acc:0.25
# Epoch: 19
#  	 Train Loss:1.18 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:2.16
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:59.47 	 Val (with Target) Acc:0.23
# Epoch: 20
#  	 Train Loss:1.19 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:2.31
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:59.69 	 Val (with Target) Acc:0.21
# Epoch: 21
#  	 Train Loss:1.20 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:2.33
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:60.99 	 Val (with Target) Acc:0.23
# Epoch: 22
#  	 Train Loss:1.23 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.15 	 Train (Replay) Loss:2.41
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:59.87 	 Val (with Target) Acc:0.22
# Epoch: 23
#  	 Train Loss:1.21 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:2.54
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:60.46 	 Val (with Target) Acc:0.23
# Epoch: 24
#  	 Train Loss:1.20 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:2.12
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:59.55 	 Val (with Target) Acc:0.19
# Epoch: 25
#  	 Train Loss:1.18 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.11 	 Train (Replay) Loss:2.18
# 	 Discriminator Loss:0.59 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:60.44 	 Val (with Target) Acc:0.25
# Epoch: 26
#  	 Train Loss:1.19 	 Train Acc:0.21
# 	 Train (Adv) Loss:1.12 	 Train (Replay) Loss:2.39
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:59.75 	 Val (with Target) Acc:0.22
# Epoch: 27
#  	 Train Loss:1.20 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:2.39
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:59.67 	 Val (with Target) Acc:0.25
# Epoch: 28
#  	 Train Loss:1.23 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.16 	 Train (Replay) Loss:2.31
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:59.55 	 Val (with Target) Acc:0.25
# Epoch: 29
#  	 Train Loss:1.21 	 Train Acc:0.21
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:2.53
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:58.52 	 Val (with Target) Acc:0.22
# Epoch: 30
#  	 Train Loss:1.20 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.13 	 Train (Replay) Loss:2.41
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:59.95 	 Val (with Target) Acc:0.25
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:2.14 	 Test (with Source) Acc:0.57
# Target Domain B:
# 	 Test (with Target) Loss:2.52 	 Test (with Target) Acc:0.58
# Target Domain C:
# 	 Test (with Target) Loss:2.52 	 Test (with Target) Acc:0.53
# Target Domain D:
# 	 Test (with Target) Loss:1.65 	 Test (with Target) Acc:0.71
# Target Domain E:
# 	 Test (with Target) Loss:93.87 	 Test (with Target) Acc:0.35
# Target Domain F:
# 	 Test (with Target) Loss:75.76 	 Test (with Target) Acc:0.23
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 14400
#
# Phase 6 (Domain F to Domain G)
# Epoch: 1
#  	 Train Loss:1.33 	 Train Acc:0.17
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:2.34
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:81.41 	 Val (with Target) Acc:0.16
# Epoch: 2
#  	 Train Loss:1.33 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:2.02
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:74.31 	 Val (with Target) Acc:0.16
# Epoch: 3
#  	 Train Loss:1.30 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.79
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:71.21 	 Val (with Target) Acc:0.16
# Epoch: 4
#  	 Train Loss:1.27 	 Train Acc:0.15
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.77
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:71.42 	 Val (with Target) Acc:0.18
# Epoch: 5
#  	 Train Loss:1.26 	 Train Acc:0.15
# 	 Train (Adv) Loss:1.20 	 Train (Replay) Loss:1.95
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:70.79 	 Val (with Target) Acc:0.17
# Epoch: 6
#  	 Train Loss:1.26 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.69
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:67.88 	 Val (with Target) Acc:0.17
# Epoch: 7
#  	 Train Loss:1.25 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.20 	 Train (Replay) Loss:1.56
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:69.27 	 Val (with Target) Acc:0.16
# Epoch: 8
#  	 Train Loss:1.23 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.18 	 Train (Replay) Loss:1.69
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:71.29 	 Val (with Target) Acc:0.17
# Epoch: 9
#  	 Train Loss:1.29 	 Train Acc:0.15
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:1.79
# 	 Discriminator Loss:0.53 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:70.90 	 Val (with Target) Acc:0.16
# Epoch: 10
#  	 Train Loss:1.26 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.90
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:71.87 	 Val (with Target) Acc:0.16
# Epoch: 11
#  	 Train Loss:1.26 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.48
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:73.36 	 Val (with Target) Acc:0.16
# Epoch: 12
#  	 Train Loss:1.28 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:1.53
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:73.12 	 Val (with Target) Acc:0.16
# Epoch: 13
#  	 Train Loss:1.28 	 Train Acc:0.15
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:1.78
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:71.89 	 Val (with Target) Acc:0.17
# Epoch: 14
#  	 Train Loss:1.28 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:1.55
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:72.42 	 Val (with Target) Acc:0.17
# Epoch: 15
#  	 Train Loss:1.29 	 Train Acc:0.17
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.51
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:72.60 	 Val (with Target) Acc:0.18
# Epoch: 16
#  	 Train Loss:1.23 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.18 	 Train (Replay) Loss:1.73
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:71.10 	 Val (with Target) Acc:0.16
# Epoch: 17
#  	 Train Loss:1.25 	 Train Acc:0.15
# 	 Train (Adv) Loss:1.20 	 Train (Replay) Loss:1.72
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:72.17 	 Val (with Target) Acc:0.16
# Epoch: 18
#  	 Train Loss:1.27 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.22 	 Train (Replay) Loss:1.60
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:73.53 	 Val (with Target) Acc:0.17
# Epoch: 19
#  	 Train Loss:1.27 	 Train Acc:0.17
# 	 Train (Adv) Loss:1.22 	 Train (Replay) Loss:1.68
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:74.03 	 Val (with Target) Acc:0.18
# Epoch: 20
#  	 Train Loss:1.29 	 Train Acc:0.17
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.76
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:73.95 	 Val (with Target) Acc:0.19
# Epoch: 21
#  	 Train Loss:1.30 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.76
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:71.97 	 Val (with Target) Acc:0.17
# Epoch: 22
#  	 Train Loss:1.27 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.22 	 Train (Replay) Loss:1.71
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:72.52 	 Val (with Target) Acc:0.19
# Epoch: 23
#  	 Train Loss:1.28 	 Train Acc:0.17
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.52
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.68
# 	 Val (with Target) Loss:73.33 	 Val (with Target) Acc:0.17
# Epoch: 24
#  	 Train Loss:1.24 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.19 	 Train (Replay) Loss:1.68
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:73.11 	 Val (with Target) Acc:0.17
# Epoch: 25
#  	 Train Loss:1.29 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.82
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:73.83 	 Val (with Target) Acc:0.18
# Epoch: 26
#  	 Train Loss:1.25 	 Train Acc:0.17
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.43
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:73.43 	 Val (with Target) Acc:0.18
# Epoch: 27
#  	 Train Loss:1.25 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.20 	 Train (Replay) Loss:1.72
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.66
# 	 Val (with Target) Loss:73.24 	 Val (with Target) Acc:0.16
# Epoch: 28
#  	 Train Loss:1.23 	 Train Acc:0.15
# 	 Train (Adv) Loss:1.18 	 Train (Replay) Loss:1.85
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.67
# 	 Val (with Target) Loss:74.63 	 Val (with Target) Acc:0.18
# Epoch: 29
#  	 Train Loss:1.28 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.22 	 Train (Replay) Loss:1.73
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:73.27 	 Val (with Target) Acc:0.18
# Epoch: 30
#  	 Train Loss:1.27 	 Train Acc:0.16
# 	 Train (Adv) Loss:1.22 	 Train (Replay) Loss:1.63
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:74.12 	 Val (with Target) Acc:0.16
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:1.61 	 Test (with Source) Acc:0.64
# Target Domain B:
# 	 Test (with Target) Loss:2.45 	 Test (with Target) Acc:0.55
# Target Domain C:
# 	 Test (with Target) Loss:2.60 	 Test (with Target) Acc:0.51
# Target Domain D:
# 	 Test (with Target) Loss:1.80 	 Test (with Target) Acc:0.62
# Target Domain E:
# 	 Test (with Target) Loss:86.08 	 Test (with Target) Acc:0.27
# Target Domain F:
# 	 Test (with Target) Loss:77.58 	 Test (with Target) Acc:0.17
# Target Domain G:
# 	 Test (with Target) Loss:90.67 	 Test (with Target) Acc:0.14
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 16800
#
# Phase 7 (Domain G to Domain H)
# Epoch: 1
#  	 Train Loss:1.38 	 Train Acc:0.23
# 	 Train (Adv) Loss:1.33 	 Train (Replay) Loss:1.76
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:102.50 	 Val (with Target) Acc:0.26
# Epoch: 2
#  	 Train Loss:1.33 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.77
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:98.95 	 Val (with Target) Acc:0.24
# Epoch: 3
#  	 Train Loss:1.32 	 Train Acc:0.22
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.62
# 	 Discriminator Loss:0.54 	 Discriminator Acc:0.74
# 	 Val (with Target) Loss:93.06 	 Val (with Target) Acc:0.25
# Epoch: 4
#  	 Train Loss:1.25 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.21 	 Train (Replay) Loss:1.37
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.72
# 	 Val (with Target) Loss:96.41 	 Val (with Target) Acc:0.27
# Epoch: 5
#  	 Train Loss:1.29 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.61
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:96.31 	 Val (with Target) Acc:0.27
# Epoch: 6
#  	 Train Loss:1.29 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.50
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.73
# 	 Val (with Target) Loss:99.94 	 Val (with Target) Acc:0.27
# Epoch: 7
#  	 Train Loss:1.31 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.53
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:98.27 	 Val (with Target) Acc:0.25
# Epoch: 8
#  	 Train Loss:1.29 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.58
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:101.09 	 Val (with Target) Acc:0.25
# Epoch: 9
#  	 Train Loss:1.30 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.52
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:103.69 	 Val (with Target) Acc:0.27
# Epoch: 10
#  	 Train Loss:1.29 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.52
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:107.81 	 Val (with Target) Acc:0.28
# Epoch: 11
#  	 Train Loss:1.33 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.64
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:108.24 	 Val (with Target) Acc:0.25
# Epoch: 12
#  	 Train Loss:1.32 	 Train Acc:0.24
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.49
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:110.47 	 Val (with Target) Acc:0.26
# Epoch: 13
#  	 Train Loss:1.34 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.30 	 Train (Replay) Loss:1.50
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:104.36 	 Val (with Target) Acc:0.27
# Epoch: 14
#  	 Train Loss:1.35 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.30 	 Train (Replay) Loss:1.57
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:103.02 	 Val (with Target) Acc:0.28
# Epoch: 15
#  	 Train Loss:1.32 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.49
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:103.22 	 Val (with Target) Acc:0.26
# Epoch: 16
#  	 Train Loss:1.29 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.52
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:104.56 	 Val (with Target) Acc:0.25
# Epoch: 17
#  	 Train Loss:1.32 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.28 	 Train (Replay) Loss:1.32
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:101.53 	 Val (with Target) Acc:0.28
# Epoch: 18
#  	 Train Loss:1.31 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.31
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:102.61 	 Val (with Target) Acc:0.27
# Epoch: 19
#  	 Train Loss:1.31 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.36
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:102.44 	 Val (with Target) Acc:0.26
# Epoch: 20
#  	 Train Loss:1.30 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.46
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:101.22 	 Val (with Target) Acc:0.28
# Epoch: 21
#  	 Train Loss:1.29 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.42
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:103.55 	 Val (with Target) Acc:0.26
# Epoch: 22
#  	 Train Loss:1.29 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.24
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:101.98 	 Val (with Target) Acc:0.29
# Epoch: 23
#  	 Train Loss:1.28 	 Train Acc:0.25
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.39
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:100.57 	 Val (with Target) Acc:0.27
# Epoch: 24
#  	 Train Loss:1.30 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.25 	 Train (Replay) Loss:1.40
# 	 Discriminator Loss:0.55 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:99.16 	 Val (with Target) Acc:0.28
# Epoch: 25
#  	 Train Loss:1.27 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.23 	 Train (Replay) Loss:1.51
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:98.12 	 Val (with Target) Acc:0.29
# Epoch: 26
#  	 Train Loss:1.28 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.33
# 	 Discriminator Loss:0.56 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:97.02 	 Val (with Target) Acc:0.26
# Epoch: 27
#  	 Train Loss:1.27 	 Train Acc:0.26
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.30
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:94.56 	 Val (with Target) Acc:0.29
# Epoch: 28
#  	 Train Loss:1.29 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.24 	 Train (Replay) Loss:1.38
# 	 Discriminator Loss:0.57 	 Discriminator Acc:0.71
# 	 Val (with Target) Loss:94.52 	 Val (with Target) Acc:0.29
# Epoch: 29
#  	 Train Loss:1.31 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.27 	 Train (Replay) Loss:1.30
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.69
# 	 Val (with Target) Loss:98.27 	 Val (with Target) Acc:0.29
# Epoch: 30
#  	 Train Loss:1.30 	 Train Acc:0.27
# 	 Train (Adv) Loss:1.26 	 Train (Replay) Loss:1.42
# 	 Discriminator Loss:0.58 	 Discriminator Acc:0.70
# 	 Val (with Target) Loss:97.44 	 Val (with Target) Acc:0.28
#
# Testing Accuracy on Previously Seen and Current Domains:
# Source Domain A:
# 	 Test (with Source) Loss:1.14 	 Test (with Source) Acc:0.72
# Target Domain B:
# 	 Test (with Target) Loss:1.63 	 Test (with Target) Acc:0.67
# Target Domain C:
# 	 Test (with Target) Loss:1.76 	 Test (with Target) Acc:0.53
# Target Domain D:
# 	 Test (with Target) Loss:0.90 	 Test (with Target) Acc:0.74
# Target Domain E:
# 	 Test (with Target) Loss:80.70 	 Test (with Target) Acc:0.19
# Target Domain F:
# 	 Test (with Target) Loss:71.85 	 Test (with Target) Acc:0.19
# Target Domain G:
# 	 Test (with Target) Loss:80.21 	 Test (with Target) Acc:0.19
# Target Domain H:
# 	 Test (with Target) Loss:126.73 	 Test (with Target) Acc:0.27
# ===> generate new replay dataset!
# generated:  (2400, 1, 4096) (2400,)
# 19200

# %%
generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_src, "cuda")
src_test_loss, src_test_acc = evaluate_src(encoder_tgt, classifier, phase='Test')
print(f'\t Test (with Source) Loss:{src_test_loss:0.2f} \t Test (with Source) Acc:{src_test_acc:0.2f}') 
for phase in range(len(target_domains)):
    if(phase == 0): # Domain A to B
        print(f'\nPhase {phase + 1} (Domain {source_domain} to Domain {target_domains[phase]})')
    else: # Domain B to C, and Domain C to D
        print(f'\nPhase {phase + 1} (Domain {target_domains[phase - 1]} to Domain {target_domains[phase]})')
    
    generate_confusion_matrix(encoder_tgt, classifier, test_dataloader_tgt[phase], "cuda")
    tgt_test_loss, tgt_test_acc = evaluate_tgt(encoder_tgt, classifier, test_dataloader_tgt[phase])
    print(f'\t Test (with Target) Loss:{tgt_test_loss:0.2f} \t Test (with Target) Acc:{tgt_test_acc:0.2f}')
# Out:
# 	 Test (with Source) Loss:1.14 	 Test (with Source) Acc:0.72
#
# Phase 1 (Domain A to Domain B)
# 	 Test (with Target) Loss:1.63 	 Test (with Target) Acc:0.67
#
# Phase 2 (Domain B to Domain C)
# 	 Test (with Target) Loss:1.76 	 Test (with Target) Acc:0.53
#
# Phase 3 (Domain C to Domain D)
# 	 Test (with Target) Loss:0.90 	 Test (with Target) Acc:0.74
#
# Phase 4 (Domain D to Domain E)
# 	 Test (with Target) Loss:80.70 	 Test (with Target) Acc:0.19
#
# Phase 5 (Domain E to Domain F)
# 	 Test (with Target) Loss:71.85 	 Test (with Target) Acc:0.19
#
# Phase 6 (Domain F to Domain G)
# 	 Test (with Target) Loss:80.21 	 Test (with Target) Acc:0.19
#
# Phase 7 (Domain G to Domain H)
# 	 Test (with Target) Loss:126.73 	 Test (with Target) Acc:0.27

# %%
def generate_features(encoder, dataloader):
    feature = encoder(dataloader.dataset.data[5].to(device))
    plt.plot(feature.detach().cpu()[0].numpy())
    plt.show()

# %%
generate_features(encoder_src, test_dataloader_src)

# %%
for i in range(len(target_domains)):
    generate_features(encoder_tgt, test_dataloader_tgt[i])
